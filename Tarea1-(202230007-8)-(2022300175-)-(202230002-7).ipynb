# %% [markdown]
# # Tarea 1 Bases de Datos 2024-1 Grupo XX
#
# _Recuerde modificar esta celda y la siguiente! (Borre esta línea también)._

# %% [markdown]
# ## Integrantes:
# * Nombre Benjamin Arias Vega - 202230007-8
# * Nombre Juan Pablo Prieto - Rol-2
# * Nombre Agustin Diaz - Rol-202230017-5

# %% [markdown]
# ## Requisitos para Correr el Notebook
#
# Para poder utilizar este Notebook se debe tener instalado:
# - **Python 3**
# - **Jupyter**
# - La librería **ipython-sql** (Poder ejecutar sql en Jupyter Notebook)
# - PostgreSQL y su conector desde Python(**psycopg2**)
#
# **IMPORTANTE:** Este Jupyter Notebook se conectará a su servicio de Base de Datos PostgreSQL de manera **local**, por lo que **no funcionará correctamente en el entorno Google Collab.**
#
# Para instalar las dependencias, ejecute (**recuerde actualizar pip3**):

# %%
! pip3 install ipython-sql

! pip3 install psycopg2
# Out:
# Requirement already satisfied: ipython-sql in c:\users\gorilla setups\appdata\local\programs\python\python312\lib\site-packages (0.5.0)
# Requirement already satisfied: prettytable in c:\users\gorilla setups\appdata\local\programs\python\python312\lib\site-packages (from ipython-sql) (3.10.0)
# Requirement already satisfied: ipython in c:\users\gorilla setups\appdata\local\programs\python\python312\lib\site-packages (from ipython-sql) (8.23.0)
# Requirement already satisfied: sqlalchemy>=2.0 in c:\users\gorilla setups\appdata\local\programs\python\python312\lib\site-packages (from ipython-sql) (2.0.29)
# Requirement already satisfied: sqlparse in c:\users\gorilla setups\appdata\local\programs\python\python312\lib\site-packages (from ipython-sql) (0.5.0)
# Requirement already satisfied: six in c:\users\gorilla setups\appdata\local\programs\python\python312\lib\site-packages (from ipython-sql) (1.16.0)
# Requirement already satisfied: ipython-genutils in c:\users\gorilla setups\appdata\local\programs\python\python312\lib\site-packages (from ipython-sql) (0.2.0)
# Requirement already satisfied: typing-extensions>=4.6.0 in c:\users\gorilla setups\appdata\local\programs\python\python312\lib\site-packages (from sqlalchemy>=2.0->ipython-sql) (4.11.0)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\gorilla setups\appdata\local\programs\python\python312\lib\site-packages (from sqlalchemy>=2.0->ipython-sql) (3.0.3)
# Requirement already satisfied: decorator in c:\users\gorilla setups\appdata\local\programs\python\python312\lib\site-packages (from ipython->ipython-sql) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\gorilla setups\appdata\local\programs\python\python312\lib\site-packages (from ipython->ipython-sql) (0.19.1)
# Requirement already satisfied: matplotlib-inline in c:\users\gorilla setups\appdata\local\programs\python\python312\lib\site-packages (from ipython->ipython-sql) (0.1.7)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in c:\users\gorilla setups\appdata\local\programs\python\python312\lib\site-packages (from ipython->ipython-sql) (3.0.43)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\gorilla setups\appdata\local\programs\python\python312\lib\site-packages (from ipython->ipython-sql) (2.17.2)
# Requirement already satisfied: stack-data in c:\users\gorilla setups\appdata\local\programs\python\python312\lib\site-packages (from ipython->ipython-sql) (0.6.3)
# Requirement already satisfied: traitlets>=5.13.0 in c:\users\gorilla setups\appdata\local\programs\python\python312\lib\site-packages (from ipython->ipython-sql) (5.14.3)
# Requirement already satisfied: colorama in c:\users\gorilla setups\appdata\local\programs\python\python312\lib\site-packages (from ipython->ipython-sql) (0.4.6)
# Requirement already satisfied: wcwidth in c:\users\gorilla setups\appdata\local\programs\python\python312\lib\site-packages (from prettytable->ipython-sql) (0.2.13)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in c:\users\gorilla setups\appdata\local\programs\python\python312\lib\site-packages (from jedi>=0.16->ipython->ipython-sql) (0.8.4)
# Requirement already satisfied: executing>=1.2.0 in c:\users\gorilla setups\appdata\local\programs\python\python312\lib\site-packages (from stack-data->ipython->ipython-sql) (2.0.1)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\gorilla setups\appdata\local\programs\python\python312\lib\site-packages (from stack-data->ipython->ipython-sql) (2.4.1)
# Requirement already satisfied: pure-eval in c:\users\gorilla setups\appdata\local\programs\python\python312\lib\site-packages (from stack-data->ipython->ipython-sql) (0.2.2)
# Requirement already satisfied: psycopg2 in c:\users\gorilla setups\appdata\local\programs\python\python312\lib\site-packages (2.9.9)

# %% [markdown]
# ## Importar dependencias

# %%
import random
from datetime import datetime, timedelta

#Librerías para PostgreSQL
import psycopg2

# %% [markdown]
# Para conectarse a la base de datos, completen los datos relevantes en la variable DATABASE_URL.
#
# * Cambie `user` por el usuario que utilizó en Postgres para acceder a la Base de Datos. Por defecto `postgres`.
# * Cambie `password` por la contraseña de dicho usuario. **Recuerde borrarla antes de entregar su tarea.**
# * Cambie `port` por el puerto en que se ejecuta su servicio de Base de Datos. Por defecto `5432`.
# * Cambie `database` por el nombre de la BD (Schema) que creó en Postgres.
#
# Ejemplo: `postgresql://postgres:pass_segura@localhost:5432/tarea-bd`

# %%
# %reload_ext sql
# %env DATABASE_URL=postgresql://postgres:holafino@localhost:5432/tarea1bd
# Out:
# env: DATABASE_URL=postgresql://postgres:holafino@localhost:5432/tarea1bd

# %% [markdown]
# Para conectarse de forma declarativa a la Base de Datos, utilice el siguiente código:

# %%
#Recuerde cambiar los valores de USER, DBNAME y PASSWORD por los mismos de la celda superior.
conn = psycopg2.connect(
   host="localhost",
   user="postgres",
   dbname='tarea1bd',
   password="holafino"
)

print(conn)
# Out:
# <connection object at 0x00000245F3027010; dsn: 'user=postgres password=xxx dbname=tarea1bd host=localhost', closed: 0>

# %% [markdown]
# ## Crear tablas
#
# Aquí inserta el código SQL que creara las tablas de la base de datos:

# %% [markdown]
# ### Tabla "Director"

# %%
# %%sql
# CREATE TABLE director (
#     id_director SERIAL PRIMARY KEY,
#     nombre VARCHAR(45),
#     edad INT
# );
# Out:
# Done.
# []

# %% [markdown]
# ### Tabla "Actor"

# %%
# %%sql
# CREATE TABLE actor (
#     id_actor SERIAL PRIMARY KEY,
#     nombre VARCHAR(45),
#     edad INT
# );
# Out:
#  * postgresql://postgres:***@localhost:5432/tarea1bd
# Done.
# []

# %% [markdown]
# ### Tabla "Pelicula"

# %%
# %%sql
# CREATE TABLE pelicula (
#     id_pelicula SERIAL PRIMARY KEY,
#     id_director INT,
#     nombre VARCHAR(45),
#     genero VARCHAR(45),
#     duracion INT,
#     fecha_publicacion DATE,
#     UNIQUE (id_pelicula)
# );
# Out:
#  * postgresql://postgres:***@localhost:5432/tarea1bd
# Done.
# []

# %% [markdown]
# ### Tabla "actor_participa_en_pelicula"

# %%
# %%sql
# CREATE TABLE actor_participa_en_pelicula (
#     id_actor INT,
#     id_pelicula INT,
#     PRIMARY KEY (id_actor, id_pelicula),
#     FOREIGN KEY (id_actor) REFERENCES actor(id_actor),
#     FOREIGN KEY (id_pelicula) REFERENCES pelicula(id_pelicula)
# );
# Out:
#  * postgresql://postgres:***@localhost:5432/tarea1bd
# Done.
# []

# %% [markdown]
# ### Tabla  "Premio_mejor_director"

# %%
# %%sql
# CREATE TABLE premio_mejor_director (
#     id_premio SERIAL,
#     id_director INT,
#     anio INT,
#     PRIMARY KEY (id_premio, id_director),
#     FOREIGN KEY (id_director) REFERENCES director(id_director)
# );
# Out:
#  * postgresql://postgres:***@localhost:5432/tarea1bd
# Done.
# []

# %% [markdown]
# ### Tabla  "Premio_mejor_actor"

# %%
# %%sql
# CREATE TABLE premio_mejor_actor (
#     id_premio SERIAL,
#     id_actor INT,
#     anio INT,
#     PRIMARY KEY (id_premio, id_actor),
#     FOREIGN KEY (id_actor) REFERENCES actor(id_actor)
# );
# Out:
#  * postgresql://postgres:***@localhost:5432/tarea1bd
# Done.
# []

# %% [markdown]
# ### Tabla  "Premio_mejor_pelicula"

# %%
# %%sql
# CREATE TABLE premio_mejor_pelicula (
#     id_premio SERIAL PRIMARY KEY,
#     id_pelicula INT,
#     anio INT,
#     FOREIGN KEY (id_pelicula) REFERENCES pelicula(id_pelicula)
# );
# Out:
#  * postgresql://postgres:***@localhost:5432/tarea1bd
# Done.
# []

# %% [markdown]
# ## Código Generador de Datos
#
# Ejecute este código para cargar datos a las tablas creadas.

# %%
import random
from datetime import date
#Prefijos y sufijos para crear nombres de peliculas aleatoriamente
prefijos = ["El misterio de", "El viaje de", "Las aventuras de", "La historia de", "El secreto de", "La leyenda de", "La búsqueda de", "El regreso de", "El tesoro de", "La odisea de", "La misión de", "La conquista de", "La travesía de", "El destino de", "El despertar de", "El último viaje de", "La venganza de", "El renacimiento de", "La rebelión de", "El vuelo de", "El descubrimiento de", "La sombra de", "La redención de", "El ritual de", "La batalla de", "El hechizo de", "El pacto de", "La profecía de", "El laberinto de", "El prisionero de", "La llegada de", "El amanecer de", "La fortuna de", "El enigma de", "La invasión de", "El resurgimiento de", "La metamorfosis de", "El eclipse de", "La danza de", "La canción de", "El lamento de", "La trampa de", "La travesura de", "El tesoro escondido de", "El vuelo mágico de", "El canto de sirena de", "El bosque encantado de", "La maldición de", "La leyenda perdida de", "La tormenta de", "El camino hacia", "El viajero de", "El guardián de", "La cripta de", "El espejismo de", "El secreto oscuro de", "La resurrección de", "La danza macabra de", "La fuga de", "La estrella fugaz de", "El grito de", "El castillo de", "La travesía sin retorno de", "La estirpe de", "La llave de", "El cuento de hadas de", "El príncipe de", "La doncella de", "El arco iris de", "La fuente de", "El refugio de", "La senda de", "La búsqueda del tesoro de", "El caballero de", "La escalada de", "La maldición del vampiro de", "La travesía del océano de"]
sufijos = ["el león", "la bailarina", "el sapo", "la estrella", "el mago", "la princesa", "el guerrero", "la criatura", "el explorador", "la bruja", "la montaña", "la isla", "el dragón", "la cueva", "el lobo", "la reina", "el rey", "la espada", "el castillo", "la flor", "la selva", "el tesoro", "la nube", "el unicornio", "la sirena", "el volcán", "la neblina", "la cascada", "el árbol", "la ciudad", "el río", "la tormenta", "la luna", "el sol", "la estrella fugaz", "el camino", "la sombra", "el laberinto", "la ola", "la caverna", "el mar", "el ángel", "la espada mágica", "el destino", "el faro", "el puente", "el horizonte", "el valle", "el puente", "la muralla", "el bosque", "la gruta", "la corona", "la aldea", "la batalla", "la noche", "el amanecer", "el atardecer", "el sueño", "la pesadilla", "el héroe", "la heroína", "la aventura", "el misterio", "la magia", "la leyenda", "la profecía", "el secreto", "el desafío", "la trampa", "la mariposa", "el jardín", "la tormenta", "la montaña", "el río", "el rincón", "el guardián", "el hechizo", "la misión", "la expedición", "la caza", "el trono", "la batalla", "la aventura", "el legado", "el enigma", "la clave", "el guardián", "el viajero", "la cripta", "el laberinto", "el abismo", "el muro", "la senda", "el laberinto", "la bruma", "la travesía", "el vuelo", "la sirena", "el hechicero", "la escuela", "la academia", "la sombra", "la estrella", "el ángel", "la gárgola", "la profecía", "la puerta", "la guerra", "el pacto", "la ley", "el viaje", "la huida", "la fortuna", "la prisión", "la cárcel", "el lamento", "la sonrisa", "el susurro", "el grito", "la fuga", "el monstruo", "la bestia", "la maraña", "el sueño", "la pesadilla", "la verdad", "el mito", "el océano", "la estrella", "el fuego", "la tierra", "el cielo", "la oscuridad", "la luz", "el caos", "la esperanza", "la promesa", "la traición", "el destino", "la salvación", "la perdición", "la soledad", "la compañía", "la amistad", "el amor", "la pasión", "la venganza", "el perdón", "el renacer", "el adiós", "la bienvenida", "la despedida", "el encuentro", "la desgracia", "la fortuna", "la guerra", "la paz", "la caída", "el renacimiento", "la resistencia", "el sacrificio", "la alianza", "el viaje", "el descubrimiento", "la revelación", "la esperanza", "la batalla", "el peligro", "la aventura", "la magia", "la pesadilla", "el misterio", "la leyenda", "la guerra", "el amor", "la traición", "la redención", "la libertad", "la prisión", "la oscuridad", "la luz", "la corrupción"]
#Nombres y apellidos para crear nombres de peliculas aleatoriamente
nombres = ["Akira", "Alessandro", "Chen", "Darius", "Emiko", "Fatemeh", "Gustavo", "Hiroko", "Isa", "Jin", "Katarina", "Lakshmi", "Mikhail", "Nina", "Omar", "Pilar", "Qiu", "Rashid", "Sakura", "Tatiana", "Umar", "Valentina", "Wang", "Xavier", "Yasmin", "Zafar", "Aarav", "Beatriz", "Chidike", "Darya", "Elif", "Fadhila", "Giovanni", "Hanako", "Ilya", "Jasmin", "Khaled", "Leticia", "Mehmet", "Nadia", "Orhan", "Parvati", "Quintus", "Rania", "Salim", "Theresa", "Ursula", "Vivek", "Wilhelmina", "Xin", "Yusef", "Zoya", "Abdullah", "Bianca", "Chiyoko", "Dmitri", "Elena", "Fabiana", "Genghis", "Han", "Irina", "Javier", "Kamala", "Leonardo", "Mina", "Natalia", "Oscar", "Patricia", "Quentin", "Rosa", "Samir", "Tatjana", "Umberto", "Valeria", "Wan", "Ximena", "Yuri", "Zara"]
apellidos = ["Abadi", "Bianchi", "Cruz", "Dutta", "Etxebarria", "Ferreira", "Gao", "Hernandez", "Ivanov", "Janssen", "Kawaguchi", "Lopez", "Montenegro", "Nguyen", "Olivares", "Petrov", "Qian", "Rodriguez", "Santos", "Tan", "Ueno", "Vargas", "Wu", "Xia", "Yilmaz", "Zhang", "Almeida", "Borges", "Carvalho", "Diniz", "Esteves", "Fernandes", "Gomes", "Henriquez", "Inácio", "Joaquim", "Lima", "Mendes", "Nogueira", "Oliveira", "Pereira", "Quintana", "Ramos", "Santana", "Teixeira", "Uchoa", "Vieira", "Xavier", "Yamamoto", "Zambrano", "Alvarez", "Barros", "Correia", "Duarte", "Estevez", "Figueiredo", "Goncalves", "Hidalgo", "Iglesias", "Jimenez", "Kumar", "Lopes", "Martinez", "Nunes", "Ortega", "Pacheco", "Queiroz", "Rocha", "Sousa", "Teles", "Urbina", "Velez", "Watanabe", "Xu", "Yan", "Zapata"]
# Definir el rango de fechas
fecha_inicial = datetime(1960, 1, 1)
fecha_final = datetime(2023, 12, 31)

# Calcular la diferencia entre las fechas inicial y final
diferencia = fecha_final - fecha_inicial

# Generar una fecha aleatoria dentro del rango
fecha_aleatoria = fecha_inicial + timedelta(days=random.randint(0, diferencia.days))

# Convertir la fecha al formato SQL DATE (YYYY-MM-DD)
fecha_sql = fecha_aleatoria.strftime('%Y-%m-%d')

cursor = conn.cursor()

premios_info = {}
directores_ids = []
for _ in range(200):
    nombre = random.choice(nombres) + " " + random.choice(apellidos)
    edad = random.randint(30,90)
    cursor.execute("INSERT INTO director (nombre, edad) VALUES (%s, %s) RETURNING id_director", (nombre, edad))
    id_director = cursor.fetchone()[0]
    directores_ids.append(id_director)
    
actores_ids = []
for _ in range(200):
    nombre = random.choice(nombres) + " " + random.choice(apellidos)
    edad = random.randint(15,70) 
    cursor.execute("INSERT INTO actor (nombre, edad) VALUES (%s, %s) RETURNING id_actor", (nombre, edad))
    id_actor = cursor.fetchone()[0]
    actores_ids.append(id_actor)

peliculas_ids = []
for _ in range(300):
    director_pelicula = random.choice(directores_ids)
    nombre = random.choice(prefijos) + " " + random.choice(sufijos)
    genero = random.choice(["Acción", "Aventura", "Animación", "Comedia", "Documental", "Drama", "Fantasía", "Terror", "Ciencia ficción", "Musical", "Misterio", "Romance", "Suspense", "Western"])
    duracion = random.randint(70,150)
    fecha_aleatoria = fecha_inicial + timedelta(days=random.randint(0, diferencia.days))
    # Convertir la fecha al formato SQL DATE (YYYY-MM-DD)
    fecha_sql = fecha_aleatoria.strftime('%Y-%m-%d')
    cursor.execute("INSERT INTO pelicula (id_director, nombre, genero, duracion, fecha_publicacion) VALUES (%s,%s,%s,%s,%s) RETURNING id_pelicula",(director_pelicula,nombre,genero,duracion,fecha_sql))
    id_pelicula = cursor.fetchone()[0]
    peliculas_ids.append(id_pelicula)
    if id_pelicula not in premios_info:
        premios_info[id_pelicula] = {}
        premios_info[id_pelicula]["año"] = fecha_aleatoria.year
        premios_info[id_pelicula]["director"] = director_pelicula
        premios_info[id_pelicula]["genero"] = genero
        premios_info[id_pelicula]["cast"] = []
        premios_info[id_pelicula]["mejor pelicula"] = "no"
    
lista_pelicula_actor = []
peliculas_actores = {}
for _ in range(500):
    peliculaID = random.choice(peliculas_ids)
    actorID = random.choice(actores_ids)
    if not (peliculaID, actorID) in lista_pelicula_actor:
        cursor.execute("INSERT INTO actor_participa_en_pelicula (id_pelicula, id_actor) VALUES (%s,%s)",(peliculaID,actorID))
        lista_pelicula_actor.append((peliculaID,actorID))
    else:
        continue


for pelicula, actor in lista_pelicula_actor:
    if pelicula in premios_info:
        premios_info[pelicula]["cast"].append(actor)

print(premios_info)
for _ in range(100):
    pelicula_al_azar = random.randint(1,300)
    tipo_de_premio = ["mejor pelicula", "mejor actor", "mejor director"]
    eleccion_premio = random.choice(tipo_de_premio)
    if eleccion_premio == "mejor director":
        if premios_info[pelicula_al_azar]["director"] != "elegido":
            director = premios_info[pelicula_al_azar]["director"]
            año = premios_info[pelicula_al_azar]["año"]
            cursor.execute("INSERT INTO premio_mejor_director (id_director, anio) VALUES (%s,%s)",(director, año))
            premios_info[pelicula_al_azar]["director"] = "elegido"
        else:
            continue
    elif eleccion_premio == "mejor actor":
        if premios_info[pelicula_al_azar]["cast"] != []:
            actor = random.choice(premios_info[pelicula_al_azar]["cast"])
            año = premios_info[pelicula_al_azar]["año"]
            cursor.execute("INSERT INTO premio_mejor_actor (id_actor, anio) VALUES (%s,%s)",(actor, año))
            premios_info[pelicula_al_azar]["cast"].remove(actor)
        else:
            continue
    elif eleccion_premio == "mejor pelicula":
        if premios_info[pelicula_al_azar]["mejor pelicula"] != "si":
            pelicula = pelicula_al_azar
            año = premios_info[pelicula_al_azar]["año"]
            cursor.execute("INSERT INTO premio_mejor_pelicula (id_pelicula, anio) VALUES (%s,%s)",(pelicula, año))
            premios_info[pelicula_al_azar]["mejor pelicula"] = "si"
        else:
            continue

conn.commit()
cursor.close()
conn.close()
# Out:
# {1201: {'año': 1969, 'director': 810, 'genero': 'Ciencia ficción', 'cast': [812, 889, 913], 'mejor pelicula': 'no'}, 1202: {'año': 1978, 'director': 944, 'genero': 'Comedia', 'cast': [842, 809], 'mejor pelicula': 'no'}, 1203: {'año': 1981, 'director': 820, 'genero': 'Romance', 'cast': [985], 'mejor pelicula': 'no'}, 1204: {'año': 1985, 'director': 809, 'genero': 'Misterio', 'cast': [], 'mejor pelicula': 'no'}, 1205: {'año': 2016, 'director': 965, 'genero': 'Animación', 'cast': [811, 829], 'mejor pelicula': 'no'}, 1206: {'año': 1981, 'director': 908, 'genero': 'Western', 'cast': [861, 843], 'mejor pelicula': 'no'}, 1207: {'año': 1999, 'director': 874, 'genero': 'Suspense', 'cast': [943], 'mejor pelicula': 'no'}, 1208: {'año': 1972, 'director': 845, 'genero': 'Romance', 'cast': [], 'mejor pelicula': 'no'}, 1209: {'año': 1977, 'director': 844, 'genero': 'Misterio', 'cast': [956], 'mejor pelicula': 'no'}, 1210: {'año': 1997, 'director': 837, 'genero': 'Animación', 'cast': [895], 'mejor pelicula': 'no'}, 1211: {'año': 2021, 'director': 836, 'genero': 'Fantasía', 'cast': [872, 928, 956, 961, 958], 'mejor pelicula': 'no'}, 1212: {'año': 2023, 'director': 808, 'genero': 'Musical', 'cast': [888, 828, 873], 'mejor pelicula': 'no'}, 1213: {'año': 2021, 'director': 946, 'genero': 'Acción', 'cast': [], 'mejor pelicula': 'no'}, 1214: {'año': 2002, 'director': 864, 'genero': 'Acción', 'cast': [984], 'mejor pelicula': 'no'}, 1215: {'año': 1995, 'director': 860, 'genero': 'Comedia', 'cast': [814, 903], 'mejor pelicula': 'no'}, 1216: {'año': 2017, 'director': 890, 'genero': 'Drama', 'cast': [831, 910, 865, 933, 954], 'mejor pelicula': 'no'}, 1217: {'año': 1961, 'director': 982, 'genero': 'Terror', 'cast': [926, 828, 910, 912, 829], 'mejor pelicula': 'no'}, 1218: {'año': 1996, 'director': 901, 'genero': 'Suspense', 'cast': [901, 882, 812, 989, 827], 'mejor pelicula': 'no'}, 1219: {'año': 2020, 'director': 971, 'genero': 'Misterio', 'cast': [934], 'mejor pelicula': 'no'}, 1220: {'año': 2001, 'director': 979, 'genero': 'Misterio', 'cast': [], 'mejor pelicula': 'no'}, 1221: {'año': 1960, 'director': 940, 'genero': 'Musical', 'cast': [886, 874, 955], 'mejor pelicula': 'no'}, 1222: {'año': 1974, 'director': 803, 'genero': 'Suspense', 'cast': [849, 956], 'mejor pelicula': 'no'}, 1223: {'año': 1975, 'director': 954, 'genero': 'Romance', 'cast': [863], 'mejor pelicula': 'no'}, 1224: {'año': 1963, 'director': 982, 'genero': 'Ciencia ficción', 'cast': [913], 'mejor pelicula': 'no'}, 1225: {'año': 1983, 'director': 895, 'genero': 'Animación', 'cast': [], 'mejor pelicula': 'no'}, 1226: {'año': 2016, 'director': 921, 'genero': 'Terror', 'cast': [], 'mejor pelicula': 'no'}, 1227: {'año': 2004, 'director': 906, 'genero': 'Acción', 'cast': [813, 966], 'mejor pelicula': 'no'}, 1228: {'año': 1978, 'director': 892, 'genero': 'Romance', 'cast': [953], 'mejor pelicula': 'no'}, 1229: {'año': 2014, 'director': 972, 'genero': 'Drama', 'cast': [867, 808], 'mejor pelicula': 'no'}, 1230: {'año': 1998, 'director': 836, 'genero': 'Drama', 'cast': [], 'mejor pelicula': 'no'}, 1231: {'año': 2009, 'director': 881, 'genero': 'Animación', 'cast': [943], 'mejor pelicula': 'no'}, 1232: {'año': 1979, 'director': 865, 'genero': 'Misterio', 'cast': [952, 990], 'mejor pelicula': 'no'}, 1233: {'año': 2015, 'director': 847, 'genero': 'Suspense', 'cast': [887], 'mejor pelicula': 'no'}, 1234: {'año': 2015, 'director': 996, 'genero': 'Misterio', 'cast': [867], 'mejor pelicula': 'no'}, 1235: {'año': 1986, 'director': 985, 'genero': 'Western', 'cast': [975, 896, 813, 990], 'mejor pelicula': 'no'}, 1236: {'año': 2022, 'director': 903, 'genero': 'Ciencia ficción', 'cast': [921, 988, 874, 915], 'mejor pelicula': 'no'}, 1237: {'año': 2019, 'director': 855, 'genero': 'Drama', 'cast': [823, 826], 'mejor pelicula': 'no'}, 1238: {'año': 1981, 'director': 925, 'genero': 'Misterio', 'cast': [832], 'mejor pelicula': 'no'}, 1239: {'año': 2009, 'director': 881, 'genero': 'Romance', 'cast': [939, 918], 'm ...
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[19], line 91
#      89         continue
#      90 elif eleccion_premio == "mejor actor":
# ---> 91     if premios_info[pelicula_al_azar]["cast"] != []:
#      92         actor = random.choice(premios_info[pelicula_al_azar]["cast"])
#      93         año = premios_info[pelicula_al_azar]["año"]
#
# KeyError: 14

# %% [markdown]
# ## Consultas
#
# Escriba aquí las consultas pedidas. Recuerde agregar una descripción _breve_ de cómo funciona la solución. **Escriba las consultas de forma ordenada.**
#
# **NOTA:** Cuando en una consulta diga "X cosa" significa que ustedes deben de elegir ese X por lo que para cualquier otro X debe de funcionar de igual forma.

# %% [markdown]
# ### Consulta 1
# **Nombre de todas las películas publicadas desde el año pasado.**
#
#
# **Ejemplo:**
# |Nombre|
# |------|
# |Dune 2|
# |...|
#
#
# **Solución:** Buscara la informacion a traves de las fechas de lanzamiento, y retornara el nombre de las peliculas.

# %%
# %%sql
# SELECT nombre
# FROM pelicula
# WHERE fecha_publicacion >= DATE '2023-01-01';
# Out:
# 6 rows affected.
# [('El tesoro de el renacer',),
#  ('El ritual de el susurro',),
#  ('El enigma de el horizonte',),
#  ('La rebelión de la guerra',),
#  ('La doncella de la soledad',),
#  ('El cuento de hadas de la leyenda',)]

# %% [markdown]
# ### Consulta 2
# **Nombre y fecha de publicación de todas las películas del género drama que hayan sido publicadas en el año 2023.**
#
#
# **Ejemplo:**
#
# |Nombre     |Fecha de publicación|
# |-----------|--------------------|
# |Oppenheimer|21-7-2023          |
# |...        |...                 |
#
#
# **Solución:** Se buscara en la base de datos a traves del nombre y fecha de publicacion

# %%
# %%sql
# SELECT nombre AS "Nombre", fecha_publicacion AS "Fecha de Publicacion"
# FROM pelicula
# WHERE genero = 'Drama'
# Out:
#  * postgresql://postgres:***@localhost:5432/tarea1bd
# 18 rows affected.
# [('El guardián de la luna', datetime.date(2001, 7, 21)),
#  ('El refugio de la gruta', datetime.date(2020, 5, 26)),
#  ('El canto de sirena de el árbol', datetime.date(2016, 11, 22)),
#  ('La tormenta de el lamento', datetime.date(2015, 5, 19)),
#  ('La danza macabra de la esperanza', datetime.date(2021, 10, 30)),
#  ('El secreto de la leyenda', datetime.date(1968, 5, 16)),
#  ('El secreto oscuro de el lamento', datetime.date(1999, 3, 8)),
#  ('La invasión de el monstruo', datetime.date(2014, 7, 20)),
#  ('El grito de la huida', datetime.date(2000, 8, 22)),
#  ('La doncella de la corona', datetime.date(2003, 8, 27)),
#  ('El prisionero de la batalla', datetime.date(2001, 10, 27)),
#  ('La tormenta de el viaje', datetime.date(1975, 2, 5)),
#  ('El destino de la espada', datetime.date(2000, 2, 3)),
#  ('La trampa de el cielo', datetime.date(1999, 11, 19)),
#  ('El descubrimiento de la tierra', datetime.date(2016, 1, 6)),
#  ('El renacimiento de la maraña', datetime.date(1980, 1, 22)),
#  ('El grito de la aventura', datetime.date(1981, 12, 26)),
#  ('La batalla de el árbol', datetime.date(1975, 3, 1))]

# %% [markdown]
# ### Consulta 3
# **Nombres de todos los actores que participaron en una película de género comedia.**
#
#
# **Ejemplo:**
# |Nombre       |
# |-------------|
# |Margot Robbie|
# |...          |
#
#
# **Solución:**  Hacer una consulta que une la tabla de actor, peliculas y luego se filtra por genero comedia, ademas de eliminar los duplicados

# %%
# %%sql
# SELECT DISTINCT a.nombre AS "Nombre"
# FROM actor a
# JOIN actor_participa_en_pelicula ap ON a.id_actor = ap.id_actor
# JOIN pelicula p ON ap.id_pelicula = p.id_pelicula
# WHERE p.genero = 'Comedia';
# Out:
#  * postgresql://postgres:***@localhost:5432/tarea1bd
# 33 rows affected.
# [('Bianca Gao',),
#  ('Bianca Xu',),
#  ('Darius Bianchi',),
#  ('Darius Figueiredo',),
#  ('Emiko Joaquim',),
#  ('Gustavo Figueiredo',),
#  ('Gustavo Rocha',),
#  ('Hanako Mendes',),
#  ('Hanako Qian',),
#  ('Hiroko Zambrano',),
#  ('Irina Figueiredo',),
#  ('Jasmin Henriquez',),
#  ('Jin Ivanov',),
#  ('Kamala Quintana',),
#  ('Katarina Estevez',),
#  ('Leonardo Iglesias',),
#  ('Mikhail Pereira',),
#  ('Mina Rodriguez',),
#  ('Mina Sousa',),
#  ('Nina Janssen',),
#  ('Omar Iglesias',),
#  ('Orhan Petrov',),
#  ('Oscar Lima',),
#  ('Quintus Ivanov',),
#  ('Salim Teles',),
#  ('Samir Lopes',),
#  ('Theresa Nunes',),
#  ('Valentina Vieira',),
#  ('Valentina Wu',),
#  ('Wan Estevez',),
#  ('Wan Yamamoto',),
#  ('Wang Dutta',),
#  ('Zafar Duarte',)]

# %% [markdown]
# ### Consulta 4
# **Nombre y cantidad de premios ganados por cada género, ordenados de mayor a menor según la cantidad de premios.**
#
#
# **Ejemplo:**
# |Género  |Cantidad de premios|
# |--------|-------------------|
# |Drama   |99                 |
# |Fantasía|29                 |
# |...     |...                |
#
#
#
# **Solución:** Cuenta la cantidad de premios ganados por genero, para eso utiliza la tabla "pelicula" para unirse con la tabla "premio_mejor_pelicula", para consecuente agrupar los resultados por genero y contar los premios de cada uno,ordenandolos de forma descendente.

# %%
# %%sql
# SELECT p.genero AS "Género", COUNT(*) AS "Cantidad de premios"
# FROM pelicula p
# JOIN premio_mejor_pelicula pm ON p.id_pelicula = pm.id_pelicula
# GROUP BY p.genero
# ORDER BY COUNT(*) DESC;
# Out:
#  * postgresql://postgres:***@localhost:5432/tarea1bd
# 13 rows affected.
# [('Fantasía', 5),
#  ('Comedia', 4),
#  ('Misterio', 4),
#  ('Terror', 3),
#  ('Suspense', 3),
#  ('Ciencia ficción', 3),
#  ('Aventura', 3),
#  ('Documental', 3),
#  ('Western', 3),
#  ('Animación', 2),
#  ('Acción', 2),
#  ('Romance', 2),
#  ('Drama', 1)]

# %% [markdown]
# ### Consulta 5
# **Mostrar peliculas que tengan 2 o mas actores/actrices ordenadas de mayor a menor segun la cantidad de actores/actrices.**
#
#
# **Ejemplo:**
# |Nombre     |Cantidad de actores|
# |-----------|-------------------|
# |Oppenheimer|7                  |
# |Poor Things|4                  |
# |...        |...                |
#
#
# **Solución:** Selecciona las peliculas que tienen al menos 2 actores o actrices. Se realiza una union entre "pelicula" y "actores_participa_en_pelicula" para obtener la info. Luego se agrupan los resultados por nombre de pelicula y se cuenta la cantidad de actores/actrices participantes en cada una.

# %%
# %%sql
# SELECT p.nombre AS "Nombre", COUNT(ap.id_actor) AS "Cantidad de actores"
# FROM pelicula p
# JOIN actor_participa_en_pelicula ap ON p.id_pelicula = ap.id_pelicula
# GROUP BY p.nombre
# HAVING COUNT(ap.id_actor) >= 2
# ORDER BY COUNT(ap.id_actor) DESC;
# Out:
#  * postgresql://postgres:***@localhost:5432/tarea1bd
# 148 rows affected.
# [('El tesoro escondido de la senda', 6),
#  ('El príncipe de la amistad', 5),
#  ('La trampa de la ciudad', 5),
#  ('El misterio de el guardián', 5),
#  ('La llegada de la aldea', 5),
#  ('La odisea de el héroe', 5),
#  ('El arco iris de la gruta', 5),
#  ('La escalada de la muralla', 5),
#  ('El secreto de la desgracia', 4),
#  ('El resurgimiento de el amanecer', 4),
#  ('La cripta de la bruja', 4),
#  ('La metamorfosis de la luz', 4),
#  ('El laberinto de el hechizo', 4),
#  ('El tesoro escondido de el misterio', 4),
#  ('El viajero de la cascada', 4),
#  ('El vuelo mágico de el volcán', 4),
#  ('La venganza de la bruja', 4),
#  ('El hechizo de la luz', 4),
#  ('La maldición de la corrupción', 4),
#  ('El arco iris de el rincón', 4),
#  ('El ritual de la sonrisa', 4),
#  ('El lamento de el hechizo', 4),
#  ('El arco iris de el amor', 4),
#  ('El regreso de la montaña', 4),
#  ('El arco iris de el laberinto', 4),
#  ('El prisionero de la bruma', 4),
#  ('La travesía de el laberinto', 3),
#  ('La estirpe de el rey', 3),
#  ('El vuelo de la selva', 3),
#  ('La travesía de el amanecer', 3),
#  ('El cuento de hadas de la profecía', 3),
#  ('La conquista de el camino', 3),
#  ('El bosque encantado de la espada mágica', 3),
#  ('La misión de el laberinto', 3),
#  ('La metamorfosis de la fortuna', 3),
#  ('La escalada de la bestia', 3),
#  ('El prisionero de el ángel', 3),
#  ('La leyenda de el guardián', 3),
#  ('La estirpe de el hechicero', 3),
#  ('Las aventuras de la esperanza', 3),
#  ('El lamento de la magia', 3),
#  ('El resurgimiento de el valle', 3),
#  ('La sombra de la espada mágica', 3),
#  ('La estirpe de el viajero', 3),
#  ('La travesía de el ángel', 3),
#  ('El canto de sirena de la resistencia', 3),
#  ('La historia de el grito', 3),
#  ('La invasión de la profecía', 3),
#  ('La doncella de la corona', 3),
#  ('La misión de la paz', 3),
#  ('La travesura de la montaña', 3),
#  ('La fuente de la redención', 3),
#  ('La batalla de el árbol', 3),
#  ('El secreto oscuro de el viajero', 3),
#  ('El canto de sirena de el rincón', 3),
#  ('La rebelión de la estrella', 3),
#  ('El canto de sirena de la aventura', 3),
#  ('La senda de la leyenda', 3),
#  ('El prisionero de la sombra', 3),
#  ('La danza macabra de la esperanza', 3),
#  ('El espejismo de el misterio', 3),
#  ('El amanecer de el rey', 3),
#  ('La batalla de la fortuna', 3),
#  ('El tesoro escondido de el fuego', 3),
#  ('El viajero de la espada mágica', 3),
#  ('El secreto oscuro de la cascada', 2),
#  ('El viaje de el ángel', 2),
#  ('El secreto oscuro de el puente', 2),
#  ('El ritual de el grito', 2),
#  ('La llave de el monstruo', 2),
#  ('El espejismo de la estrella fugaz', 2),
#  ('El cuento de hadas de el laberinto', 2),
#  ('La rebelión de la academia', 2),
#  ('La cripta de la batalla', 2),
#  ('El secreto oscuro de el sol', 2),
#  ('El canto de sirena de el encuentro', 2),
#  ('La odisea de la travesía', 2),
#  ('La rebelión de la guerra', 2),
#  ('El guardián de la luna', 2),
#  ('La venganza de el laberinto', 2),
#  ('La canción de el secreto', 2),
#  ('El caballero de la flor', 2),
#  ('La rebelión de la noche', 2),
#  ('La llegada de la despedida', 2),
#  ('La travesía del océano de la prisión', 2),
#  ('El viaje de el río', 2),
#  ('El amanecer de el héroe', 2),
#  ('La historia de la verdad', 2),
#  ('La fuga de la espada mágica', 2),
#  ('La venganza de la alianza', 2),
#  ('La batalla de la sombra', 2),
#  ('El viaje de el árbol', 2),
#  ('El camino hacia la luna', 2),
#  ('La travesura de la redención', 2),
#  ('El vuelo mágico de el legado', 2),
#  ('La búsqueda de la estrella', 2),
#  ('La invasión de la travesía', 2),
#  ('La trampa de el león', 2),
#  ('La fuga de el amanecer', 2),
#  ('El ritual de el susurro', 2),
#  ('La doncella de la muralla', 2),
#  ('El eclipse de la aventura', 2),
#  ('La danza macabra de el héroe', 2),
#  ('El refugio de la gruta', 2),
#  ('El guardián de el valle', 2),
#  ('El tesoro escondido de la venganza', 2),
#  ('El castillo de la profecía', 2),
#  ('La fuente de la aventura', 2),
#  ('El destino de la espada', 2),
#  ('El cuento de hadas de el mito', 2),
#  ('El misterio de el pacto', 2),
#  ('El castillo de la senda', 2),
#  ('Las aventuras de la corrupción', 2),
#  ('El enigma de la luz', 2),
#  ('El despertar de la esperanza', 2),
#  ('La leyenda de la cripta', 2),
#  ('El camino hacia la alianza', 2),
#  ('La cripta de el hechizo', 2),
#  ('El espejismo de la academia', 2),
#  ('El secreto oscuro de la traición', 2),
#  ('La estirpe de la gruta', 2),
#  ('La trampa de la cárcel', 2),
#  ('La doncella de la gruta', 2),
#  ('El renacimiento de la revelación', 2),
#  ('El tesoro escondido de la luna', 2),
#  ('La travesía sin retorno de la guerra', 2),
#  ('El caballero de el horizonte', 2),
#  ('La leyenda de la guerra', 2),
#  ('La metamorfosis de la magia', 2),
#  ('El viaje de la corona', 2),
#  ('La metamorfosis de el abismo', 2),
#  ('La estirpe de el amor', 2),
#  ('El guardián de el guerrero', 2),
#  ('El castillo de el guardián', 2),
#  ('El bosque encantado de el lamento', 2),
#  ('La odisea de la redención', 2),
#  ('El viajero de la sirena', 2),
#  ('El misterio de la sombra', 2),
#  ('El prisionero de el amanecer', 2),
#  ('La resurrección de la traición', 2),
#  ('La travesía de el muro', 2),
#  ('El caballero de la muralla', 2),
#  ('El destino de la estrella', 2),
#  ('La redención de el muro', 2),
#  ('La leyenda perdida de la selva', 2),
#  ('La travesura de el laberinto', 2),
#  ('La venganza de la resistencia', 2),
#  ('El despertar de el jardín', 2)]

# %% [markdown]
# ### Consulta 6
# **Nombre de la película con la mayor brecha de edad entre el actor más joven y el actor más viejo que participen en ella, y las edades de dichos actores.** (Si hay empate, mostrar solamente uno).
#
#
# **Ejemplo:**
# |Nombre|Edad del actor más joven|Edad del actor más viejo|
# |------|------------------------|------------------------|
# |Barbie|16                      |92                      |
#
#
# **Solución:** Se busca la pelicula que tenga mayor diferencia de edad entre sus actores participantes, para esto se realiza una union entre las tablas "pelicula", "actor_participa_en_pelicula" y "actor". Asi despues se agrupan los reslutados por nombre de pelicula y se calcula la diferencia de edad, entre el actor mas joven y el mas viejo en cada una, para finalmente ordenarlos de manera descendente y solo se muestra el mayor resultado (que seria la peli con la mayor brecha de edad entre sus actores).

# %%
# %%sql
# SELECT p.nombre AS "Nombre",
#     MIN(a.edad) AS "Edad del actor más joven",
#     MAX(a.edad) AS "Edad del actor más viejo"
# FROM pelicula p
# JOIN actor_participa_en_pelicula ap ON p.id_pelicula = ap.id_pelicula
# JOIN actor a ON ap.id_actor = a.id_actor
# GROUP BY p.nombre
# ORDER BY (MAX(a.edad) - MIN(a.edad)) DESC
# LIMIT 1;
# Out:
#  * postgresql://postgres:***@localhost:5432/tarea1bd
# 1 rows affected.
# [('La metamorfosis de la fortuna', 16, 69)]

# %% [markdown]
# ### Consulta 7
# **Año de cada premio ganado por la película de mayor duración.** (Si hay empate, elegir solamente uno).
#
#
# **Ejemplo:**
# |Año |
# |----|
# |2024|
# |... |
#
#
# **Solución:** Se identifican primero las peliculas premiadas, luego se ordenan por duracion y seleccionamos el año de la que tenga mayor duracion.

# %%
# %%sql
# WITH peliculas_premiadas AS (
#     SELECT pm.anio, p.id_pelicula, p.nombre, p.duracion,
#            ROW_NUMBER() OVER (PARTITION BY pm.anio ORDER BY p.duracion DESC) AS ranking
#     FROM premio_mejor_pelicula pm
#     JOIN pelicula p ON pm.id_pelicula = p.id_pelicula
# ),
# pelicula_max_duracion AS (
#     SELECT anio, id_pelicula, nombre, duracion
#     FROM peliculas_premiadas
#     WHERE ranking = 1
# )
# SELECT anio
# FROM pelicula_max_duracion;
# Out:
#  * postgresql://postgres:***@localhost:5432/tarea1bd
# 29 rows affected.
# [(1961,),
#  (1962,),
#  (1963,),
#  (1966,),
#  (1968,),
#  (1972,),
#  (1973,),
#  (1974,),
#  (1975,),
#  (1976,),
#  (1979,),
#  (1980,),
#  (1982,),
#  (1984,),
#  (1985,),
#  (1986,),
#  (1987,),
#  (1993,),
#  (2000,),
#  (2001,),
#  (2006,),
#  (2008,),
#  (2011,),
#  (2012,),
#  (2013,),
#  (2014,),
#  (2020,),
#  (2021,),
#  (2023,)]

# %% [markdown]
# ### Consulta 8
# **Nombre de todos los actores que han trabajado con más de un director, la cantidad de directores con las que han trabajado y el nombre de una de las películas.**
#
#
# **Ejemplo:**
# |Nombre del actor|Cantidad de directores|Nombre de una película|
# |----------------|----------------------|----------------------|
# |Cillian Murphy  |29                    |Oppenheimer           |
# |...             |...                   |...                   |
#
#
# **Solución:**  Se unen las tablas de actores, peliculas y directores en la consulta, luego se agrupa por nombre de actor y filtrar a aquellos que hayan trabajado con mas de un director, finalmente se muestra alguna pelicula

# %%
# %%sql
# SELECT a.nombre AS "Nombre del actor",
#        COUNT(DISTINCT d.id_director) AS "Cantidad de directores",
#        ANY_VALUE(p.nombre) AS "Nombre de una película"
# FROM actor_participa_en_pelicula ap
# JOIN actor a ON ap.id_actor = a.id_actor
# JOIN pelicula p ON ap.id_pelicula = p.id_pelicula
# JOIN director d ON p.id_director = d.id_director
# GROUP BY a.nombre
# HAVING COUNT(DISTINCT d.id_director) > 1;
# Out:
#  * postgresql://postgres:***@localhost:5432/tarea1bd
# 132 rows affected.
# [('Aarav Quintana', 6, 'La venganza de la bruja'),
#  ('Abdullah Yan', 6, 'La tormenta de el lamento'),
#  ('Akira Iglesias', 4, 'La metamorfosis de la fortuna'),
#  ('Alessandro Gomes', 3, 'El arco iris de el rincón'),
#  ('Alessandro Inácio', 3, 'La estirpe de el amor'),
#  ('Alessandro Teles', 2, 'El hechizo de la luz'),
#  ('Bianca Gao', 9, 'El canto de sirena de la aventura'),
#  ('Bianca Jimenez', 5, 'El secreto de la traición'),
#  ('Bianca Xu', 2, 'La travesura de el laberinto'),
#  ('Chen Duarte', 2, 'La batalla de la sombra'),
#  ('Chen Santana', 3, 'El eclipse de la aventura'),
#  ('Chen Xia', 2, 'La estirpe de el rey'),
#  ('Chidike Inácio', 2, 'La fuga de la magia'),
#  ('Chidike Pacheco', 5, 'La estirpe de el hechicero'),
#  ('Chiyoko Yilmaz', 4, 'El despertar de el jardín'),
#  ('Darius Bianchi', 7, 'La resurrección de la traición'),
#  ('Darius Duarte', 2, 'La batalla de el árbol'),
#  ('Darius Figueiredo', 4, 'El tesoro escondido de el misterio'),
#  ('Darius Montenegro', 2, 'La batalla de el mar'),
#  ('Dmitri Estevez', 3, 'El bosque encantado de la espada mágica'),
#  ('Dmitri Nguyen', 4, 'El tesoro escondido de la venganza'),
#  ('Dmitri Yilmaz', 3, 'La conquista de el camino'),
#  ('Elena Gomes', 3, 'El amanecer de el rey'),
#  ('Elena Uchoa', 5, 'La escalada de la muralla'),
#  ('Elif Estevez', 2, 'La danza macabra de el héroe'),
#  ('Elif Kawaguchi', 6, 'El cuento de hadas de la leyenda'),
#  ('Elif Quintana', 3, 'El laberinto de el hechizo'),
#  ('Elif Tan', 3, 'El espejismo de la estrella fugaz'),
#  ('Emiko Diniz', 2, 'El enigma de la luz'),
#  ('Emiko Ferreira', 5, 'La venganza de la bruja'),
#  ('Emiko Joaquim', 3, 'El viaje de la corona'),
#  ('Emiko Martinez', 4, 'El amanecer de el rey'),
#  ('Fabiana Diniz', 3, 'La metamorfosis de el abismo'),
#  ('Fabiana Lopez', 3, 'La fuga de la caza'),
#  ('Fabiana Xavier', 5, 'La odisea de la travesía'),
#  ('Fadhila Oliveira', 2, 'El laberinto de el hechizo'),
#  ('Fadhila Tan', 4, 'La travesía de el ángel'),
#  ('Fadhila Teixeira', 3, 'La metamorfosis de la magia'),
#  ('Genghis Cruz', 4, 'La travesía de el ángel'),
#  ('Genghis Uchoa', 2, 'El secreto oscuro de el lamento'),
#  ('Giovanni Borges', 4, 'El secreto oscuro de el sol'),
#  ('Giovanni Oliveira', 5, 'La metamorfosis de la fortuna'),
#  ('Gustavo Figueiredo', 6, 'La cripta de la bruja'),
#  ('Gustavo Qian', 2, 'El enigma de la guerra'),
#  ('Gustavo Queiroz', 4, 'La venganza de la bruja'),
#  ('Gustavo Rocha', 4, 'La conquista de el camino'),
#  ('Gustavo Velez', 2, 'El canto de sirena de el rincón'),
#  ('Gustavo Vieira', 2, 'La doncella de la muralla'),
#  ('Hanako Mendes', 3, 'El viajero de la sirena'),
#  ('Hanako Qian', 3, 'La travesía sin retorno de la batalla'),
#  ('Ilya Janssen', 5, 'El camino hacia la luna'),
#  ('Irina Figueiredo', 2, 'El viajero de la cascada'),
#  ('Irina Yilmaz', 4, 'La escalada de la muralla'),
#  ('Isa Correia', 4, 'La metamorfosis de el adiós'),
#  ('Isa Gao', 4, 'La rebelión de la guerra'),
#  ('Isa Gomes', 2, 'El secreto de el atardecer'),
#  ('Isa Wu', 4, 'El prisionero de la bruma'),
#  ('Jasmin Henriquez', 4, 'El canto de sirena de el rincón'),
#  ('Jin Ivanov', 2, 'El espejismo de el misterio'),
#  ('Kamala Quintana', 4, 'La estirpe de el hechicero'),
#  ('Katarina Bianchi', 5, 'La cripta de la batalla'),
#  ('Katarina Estevez', 3, 'El lamento de la magia'),
#  ('Lakshmi Inácio', 2, 'El arco iris de el amor'),
#  ('Lakshmi Rodriguez', 3, 'El destino de la estrella'),
#  ('Lakshmi Yilmaz', 2, 'El príncipe de la amistad'),
#  ('Leonardo Iglesias', 5, 'La cripta de la bruja'),
#  ('Leticia Joaquim', 2, 'El regreso de la montaña'),
#  ('Mehmet Goncalves', 2, 'La venganza de el trono'),
#  ('Mikhail Inácio', 6, 'El amanecer de el rey'),
#  ('Mikhail Pereira', 4, 'La maldición del vampiro de la senda'),
#  ('Mina Qian', 3, 'La rebelión de la estrella'),
#  ('Mina Rodriguez', 3, 'La fuente de la redención'),
#  ('Mina Sousa', 3, 'La cripta de el hechizo'),
#  ('Nadia Cruz', 3, 'El tesoro escondido de la venganza'),
#  ('Nadia Rocha', 3, 'El secreto de el peligro'),
#  ('Nadia Tan', 3, 'El bosque encantado de la mariposa'),
#  ('Nadia Urbina', 5, 'El caballero de el horizonte'),
#  ('Nina Duarte', 5, 'La venganza de la bruja'),
#  ('Nina Janssen', 4, 'La cripta de la batalla'),
#  ('Nina Santos', 2, 'La batalla de la fortuna'),
#  ('Nina Urbina', 4, 'La llegada de la aldea'),
#  ('Omar Iglesias', 5, 'El espejismo de la estrella fugaz'),
#  ('Orhan Petrov', 2, 'El príncipe de la amistad'),
#  ('Pilar Nguyen', 3, 'La odisea de el héroe'),
#  ('Qiu Oliveira', 3, 'El destino de la ley'),
#  ('Quentin Estevez', 2, 'La metamorfosis de la fortuna'),
#  ('Quentin Pereira', 3, 'El lamento de la aldea'),
#  ('Quintus Hidalgo', 3, 'La venganza de la resistencia'),
#  ('Quintus Ivanov', 3, 'La doncella de la corona'),
#  ('Quintus Teixeira', 3, 'La batalla de la fortuna'),
#  ('Rashid Lima', 4, 'El enigma de la paz'),
#  ('Rashid Nogueira', 3, 'La invasión de el monstruo'),
#  ('Rashid Nunes', 5, 'El prisionero de la bruma'),
#  ('Rosa Santana', 4, 'La historia de la verdad'),
#  ('Rosa Santos', 4, 'El lamento de la magia'),
#  ('Sakura Xu', 3, 'La travesura de la redención'),
#  ('Salim Figueiredo', 4, 'El secreto oscuro de la cascada'),
#  ('Salim Iglesias', 3, 'El misterio de el pacto'),
#  ('Salim Teles', 7, 'La conquista de el camino'),
#  ('Samir Lopes', 7, 'El laberinto de el hechizo'),
#  ('Samir Oliveira', 2, 'La escalada de la muralla'),
#  ('Tatiana Zhang', 3, 'La fuente de la muralla'),
#  ('Tatjana Zambrano', 2, 'La historia de el grito'),
#  ('Theresa Cruz', 4, 'El refugio de la gruta'),
#  ('Theresa Nunes', 3, 'La profecía de el puente'),
#  ('Umberto Teles', 3, 'El prisionero de el ángel'),
#  ('Ursula Lima', 2, 'La escalada de la muralla'),
#  ('Ursula Velez', 3, 'El espejismo de el río'),
#  ('Valentina Wu', 3, 'El tesoro escondido de el misterio'),
#  ('Valeria Lopez', 3, 'El enigma de el lobo'),
#  ('Valeria Vargas', 2, 'La trampa de la ciudad'),
#  ('Vivek Lima', 4, 'El prisionero de el ángel'),
#  ('Vivek Nogueira', 4, 'El viaje de el río'),
#  ('Vivek Xu', 4, 'La estirpe de el hechicero'),
#  ('Wan Estevez', 3, 'El vuelo mágico de el legado'),
#  ('Wan Qian', 2, 'La travesía de el laberinto'),
#  ('Wang Iglesias', 2, 'La escalada de la muralla'),
#  ('Wang Velez', 5, 'El príncipe de la caza'),
#  ('Xavier Barros', 2, 'El caballero de el horizonte'),
#  ('Xavier Rodriguez', 3, 'La rebelión de el unicornio'),
#  ('Xavier Watanabe', 5, 'El renacimiento de la revelación'),
#  ('Yasmin Zambrano', 2, 'La travesía de el ángel'),
#  ('Yusef Joaquim', 4, 'El viaje de el árbol'),
#  ('Zafar Hidalgo', 2, 'El regreso de la montaña'),
#  ('Zafar Queiroz', 3, 'La odisea de la estrella'),
#  ('Zafar Xavier', 2, 'La fortuna de el tesoro'),
#  ('Zafar Yilmaz', 2, 'La senda de la leyenda'),
#  ('Zara Almeida', 2, 'La batalla de la fortuna'),
#  ('Zara Kawaguchi', 2, 'El prisionero de el ángel'),
#  ('Zoya Janssen', 4, 'La misión de el laberinto'),
#  ('Zoya Lopes', 4, 'La odisea de la travesía'),
#  ('Zoya Lopez', 4, 'La travesía de la cárcel')]

# %% [markdown]
# ### Consulta 9
#
# **Nombre de todos los actores que han participado sólo en películas dirigidas por el director con id\_director 1.**
#
#
# **Ejemplo:**
# |Nombre      |
# |------------|
# |Ryan Gosling|
# |...         |
#
#
# **Solución:** Se buscan los actores que solo han participado en peliculas hechas por id_director 1. Se filtran las peliculas de ese director y excluimos a los otros directores, mostrano los actores que cumplen con la condicion

# %%
# %%sql
# SELECT DISTINCT a.nombre
# FROM actor a
# JOIN actor_participa_en_pelicula ap ON a.id_actor = ap.id_actor
# JOIN pelicula p ON ap.id_pelicula = p.id_pelicula
# WHERE p.id_director = 1
# AND NOT EXISTS (
#     SELECT 1
#     FROM pelicula p2
#     WHERE p2.id_director != 1
#     AND p2.id_pelicula = ap.id_pelicula
# );
# Out:
#  * postgresql://postgres:***@localhost:5432/tarea1bd
# 7 rows affected.
# [('Akira Iglesias',),
#  ('Giovanni Oliveira',),
#  ('Quentin Estevez',),
#  ('Rashid Nogueira',),
#  ('Umberto Teles',),
#  ('Vivek Lima',),
#  ('Zara Kawaguchi',)]

# %% [markdown]
# ### Consulta BONUS
#
# **Nombre de todos los actores que nunca han ganado un premio, todas las películas en las que han participado y el nombre, número total de películas y número total de premios de los directores de cada película.**
#
#
# **Ejemplo:**
# |Nombre del actor|Nombre de la película|Nombre del director|Número de películas del director|Número de premios del director|
# |----------------|---------------------|-------------------|--------------------------------|-----------------------|
# |Mark Ruffalo    |Poor Things          |Yorgos Lanthimos   |4                               |0                      |
# |Saoirse Ronan   |Lady Bird            |Greta Gerwig       |20                              |1                      |
# |Saoirse Ronan   |Little Women         |Greta Gerwig       |20                              |1                      |
# |...             |...                  |...                |...                             |...                    |
#
#
# **Solución:** Se excluyen a todos los actores que esten en actor y mejor actor, de esta manera solo nos quedamos con los que no tienen premios, luego se observa las peliculas que han participado y de aqui obtenemos el nombre de la pelicula, el numero total de peliculas dirigidas por el director, el nombre del director, y de ahi el numero de premios del director.

# %%
# %%sql
# WITH actores_sin_premio AS (
#     SELECT DISTINCT a.id_actor, a.nombre
#     FROM actor a
#     LEFT JOIN premio_mejor_actor pma ON a.id_actor = pma.id_actor
#     WHERE pma.id_actor IS NULL
# ),
# pelis_actores AS (
#     SELECT a.id_actor, a.nombre AS nombre_actor, pap.id_pelicula
#     FROM actores_sin_premio a
#     JOIN actor_participa_en_pelicula pap ON a.id_actor = pap.id_actor
# ),
# info_pelis AS (
#     SELECT pa.id_pelicula, pa.id_director, pa.nombre AS nombre_pelicula,
#            d.nombre AS nombre_director,
#            COUNT(pa.id_pelicula) OVER(PARTITION BY pa.id_director) AS num_pelis_director,
#            COUNT(pmd.id_premio) OVER(PARTITION BY pa.id_director) AS num_premios_director
#     FROM pelicula pa
#     JOIN director d ON pa.id_director = d.id_director
#     LEFT JOIN premio_mejor_director pmd ON pa.id_director = pmd.id_director
# ),
# resultado AS (
#     SELECT DISTINCT ps.id_actor, ps.nombre_actor, ip.nombre_pelicula,
#            ip.nombre_director, ip.num_pelis_director, ip.num_premios_director
#     FROM pelis_actores ps
#     JOIN info_pelis ip ON ps.id_pelicula = ip.id_pelicula
# )
# SELECT *
# FROM resultado
# ORDER BY nombre_actor, nombre_pelicula;
# Out:
#  * postgresql://postgres:***@localhost:5432/tarea1bd
# 397 rows affected.
# [(20, 'Aarav Quintana', 'El cuento de hadas de el laberinto', 'Ilya Olivares', 2, 0),
#  (20, 'Aarav Quintana', 'La danza macabra de la esperanza', 'Zoya Kawaguchi', 1, 0),
#  (20, 'Aarav Quintana', 'La llave de el destino', 'Zara Inácio', 2, 0),
#  (20, 'Aarav Quintana', 'La rebelión de la estrella', 'Beatriz Oliveira', 4, 0),
#  (20, 'Aarav Quintana', 'La redención de el muro', 'Fadhila Teles', 1, 0),
#  (20, 'Aarav Quintana', 'La venganza de la bruja', 'Fatemeh Kumar', 1, 0),
#  (12, 'Abdullah Almeida', 'La danza macabra de la esperanza', 'Zoya Kawaguchi', 1, 0),
#  (169, 'Abdullah Kumar', 'El viaje de el enigma', 'Aarav Oliveira', 2, 0),
#  (86, 'Abdullah Yan', 'El arco iris de la gruta', 'Katarina Nogueira', 3, 0),
#  (86, 'Abdullah Yan', 'El caballero de la flor', 'Tatiana Yan', 3, 0),
#  (86, 'Abdullah Yan', 'La danza macabra de la esperanza', 'Zoya Kawaguchi', 1, 0),
#  (86, 'Abdullah Yan', 'La llave de la salvación', 'Darius Martinez', 2, 0),
#  (86, 'Abdullah Yan', 'La tormenta de el lamento', 'Isa Qian', 2, 0),
#  (86, 'Abdullah Yan', 'La travesía sin retorno de la guerra', 'Theresa Etxebarria', 2, 0),
#  (33, 'Akira Iglesias', 'El espejismo de el sol', 'Natalia Gao', 4, 0),
#  (33, 'Akira Iglesias', 'La búsqueda de la estrella', 'Khaled Vargas', 1, 0),
#  (33, 'Akira Iglesias', 'La metamorfosis de la fortuna', 'Quentin Vargas', 3, 0),
#  (33, 'Akira Iglesias', 'La misión de la paz', 'Nina Uchoa', 2, 0),
#  (47, 'Alessandro Gomes', 'El arco iris de el laberinto', 'Tatiana Kawaguchi', 2, 0),
#  (47, 'Alessandro Gomes', 'El arco iris de el rincón', 'Beatriz Oliveira', 4, 0),
#  (47, 'Alessandro Gomes', 'El resurgimiento de el amanecer', 'Khaled Watanabe', 3, 0),
#  (60, 'Alessandro Inácio', 'El regreso de la montaña', 'Jin Wu', 3, 3),
#  (60, 'Alessandro Inácio', 'La estirpe de el amor', 'Isa Lima', 2, 0),
#  (60, 'Alessandro Inácio', 'La sombra de la batalla', 'Qiu Gomes', 2, 0),
#  (99, 'Alessandro Teles', 'El castillo de el guardián', 'Patricia Hidalgo', 3, 3),
#  (99, 'Alessandro Teles', 'El hechizo de la luz', 'Rosa Wu', 4, 0),
#  (163, 'Bianca Gao', 'El canto de sirena de la aventura', 'Jin Olivares', 1, 0),
#  (163, 'Bianca Gao', 'El destino de la estrella', 'Qiu Gomes', 2, 0),
#  (163, 'Bianca Gao', 'El espejismo de la academia', 'Salim Barros', 3, 0),
#  (163, 'Bianca Gao', 'El guardián de el valle', 'Rania Cruz', 2, 0),
#  (163, 'Bianca Gao', 'El ritual de la sonrisa', 'Yasmin Nguyen', 2, 0),
#  (163, 'Bianca Gao', 'El viajero de la espada mágica', 'Kamala Olivares', 3, 3),
#  (163, 'Bianca Gao', 'La leyenda de la cripta', 'Akira Qian', 3, 0),
#  (163, 'Bianca Gao', 'La leyenda de la guerra', 'Beatriz Santos', 1, 0),
#  (163, 'Bianca Gao', 'La rebelión de la guerra', 'Katarina Pacheco', 4, 4),
#  (119, 'Bianca Quintana', 'La leyenda de la guerra', 'Beatriz Santos', 1, 0),
#  (178, 'Bianca Vargas', 'El cuento de hadas de el laberinto', 'Ilya Olivares', 2, 0),
#  (90, 'Chen Duarte', 'El resurgimiento de el amanecer', 'Khaled Watanabe', 3, 0),
#  (90, 'Chen Duarte', 'La batalla de la sombra', 'Lakshmi Nguyen', 4, 4),
#  (188, 'Chen Santana', 'El eclipse de la aventura', 'Beatriz Oliveira', 4, 0),
#  (188, 'Chen Santana', 'La historia de el vuelo', 'Patricia Hidalgo', 3, 3),
#  (188, 'Chen Santana', 'La venganza de el laberinto', 'Ilya Olivares', 2, 0),
#  (177, 'Chen Xia', 'El bosque encantado de la espada mágica', 'Ilya Zapata', 3, 0),
#  (177, 'Chen Xia', 'La estirpe de el rey', 'Natalia Ortega', 1, 0),
#  (26, 'Chidike Ferreira', 'El bosque encantado de la espada mágica', 'Ilya Zapata', 3, 0),
#  (132, 'Chidike Inácio', 'El vuelo de la selva', 'Zara Abadi', 10, 10),
#  (132, 'Chidike Inácio', 'La fuga de la magia', 'Parvati Nguyen', 3, 0),
#  (7, 'Chidike Pacheco', 'El arco iris de el amor', 'Yuri Almeida', 2, 0),
#  (7, 'Chidike Pacheco', 'El resurgimiento de el valle', 'Jin Bianchi', 3, 0),
#  (7, 'Chidike Pacheco', 'La estirpe de el hechicero', 'Xavier Teixeira', 1, 0),
#  (7, 'Chidike Pacheco', 'La metamorfosis de la luz', 'Sakura Joaquim', 2, 2),
#  (7, 'Chidike Pacheco', 'La rebelión de la estrella', 'Beatriz Oliveira', 4, 0),
#  (146, 'Chiyoko Diniz', 'El príncipe de el tesoro', 'Rania Cruz', 2, 0),
#  (53, 'Chiyoko Yilmaz', 'El despertar de el jardín', 'Valeria Kumar', 3, 0),
#  (53, 'Chiyoko Yilmaz', 'El viajero de la cascada', 'Xavier Yilmaz', 2, 2),
#  (53, 'Chiyoko Yilmaz', 'La venganza de la alianza', 'Valeria Lopez', 2, 2),
#  (53, 'Chiyoko Yilmaz', 'Las aventuras de la esperanza', 'Ilya Ferreira', 1, 0),
#  (186, 'Darius Bianchi', 'El destino de el misterio', 'Zafar Cruz', 4, 0),
#  (186, 'Darius Bianchi', 'El destino de la espada', 'Tatiana Barros', 2, 0),
#  (186, 'Darius Bianchi', 'La escalada de la bestia', 'Wan Joaquim', 4, 0),
#  (118, 'Darius Duarte', 'El bosque encantado de el viaje', 'Abdullah Alvarez', 1, 0),
#  (118, 'Darius Duarte', 'La batalla de el árbol', 'Lakshmi Nguyen', 4, 4),
#  (128, 'Darius Figueiredo', 'El enigma de la luz', 'Umar Zapata', 2, 0),
#  (128, 'Darius Figueiredo', 'El espejismo de el misterio', 'Elif Goncalves', 4, 0),
#  (128, 'Darius Figueiredo', 'El guardián de la luna', 'Valeria Kumar', 3, 0),
#  (128, 'Darius Figueiredo', 'El tesoro escondido de el misterio', 'Yuri Almeida', 2, 0),
#  (133, 'Darius Montenegro', 'El vuelo de la selva', 'Zara Abadi', 10, 10),
#  (133, 'Darius Montenegro', 'La batalla de el mar', 'Xin Xia', 1, 0),
#  (122, 'Dmitri Estevez', 'El bosque encantado de la espada mágica', 'Ilya Zapata', 3, 0),
#  (122, 'Dmitri Estevez', 'El tesoro escondido de la senda', 'Dmitri Ferreira', 1, 0),
#  (122, 'Dmitri Estevez', 'La llegada de la aldea', 'Isa Joaquim', 1, 0),
#  (77, 'Dmitri Ivanov', 'La trampa de la ciudad', 'Jasmin Joaquim', 3, 0),
#  (49, 'Dmitri Nguyen', 'El canto de sirena de el encuentro', 'Beatriz Oliveira', 4, 0),
#  (49, 'Dmitri Nguyen', 'El enigma de el horizonte', 'Alessandro Petrov', 1, 0),
#  (49, 'Dmitri Nguyen', 'El grito de la aventura', 'Wang Correia', 2, 0),
#  (49, 'Dmitri Nguyen', 'El tesoro escondido de la venganza', 'Hanako Janssen', 4, 0),
#  (123, 'Elena Montenegro', 'El viaje de el ángel', 'Tatiana Kawaguchi', 2, 0),
#  (6, 'Elena Uchoa', 'El arco iris de la gruta', 'Katarina Nogueira', 3, 0),
#  (6, 'Elena Uchoa', 'El lamento de la caza', 'Akira Qian', 3, 0),
#  (6, 'Elena Uchoa', 'La escalada de la muralla', 'Umar Ueno', 3, 3),
#  (6, 'Elena Uchoa', 'La metamorfosis de la magia', 'Valentina Rocha', 1, 0),
#  (6, 'Elena Uchoa', 'La travesía del océano de la ola', 'Aarav Henriquez', 1, 0),
#  (62, 'Elif Estevez', 'La danza macabra de el héroe', 'Natalia Qian', 1, 0),
#  (62, 'Elif Estevez', 'La leyenda de la cripta', 'Akira Qian', 3, 0),
#  (8, 'Elif Kawaguchi', 'El cuento de hadas de la leyenda', 'Rosa Sousa', 3, 0),
#  (8, 'Elif Kawaguchi', 'El misterio de la sombra', 'Beatriz Estevez', 2, 0),
#  (8, 'Elif Kawaguchi', 'El secreto oscuro de el puente', 'Yuri Vargas', 3, 0),
#  (8, 'Elif Kawaguchi', 'El secreto oscuro de el viajero', 'Wang Teles', 1, 0),
#  (8, 'Elif Kawaguchi', 'La llave de el monstruo', 'Elena Teles', 2, 0),
#  (8, 'Elif Kawaguchi', 'La travesura de la redención', 'Lakshmi Nguyen', 4, 4),
#  (50, 'Elif Quintana', 'El despertar de la esperanza', 'Jasmin Joaquim', 3, 0),
#  (50, 'Elif Quintana', 'El laberinto de el hechizo', 'Pilar Ferreira', 3, 0),
#  (50, 'Elif Quintana', 'El tesoro escondido de el fuego', 'Zafar Cruz', 4, 0),
#  (59, 'Elif Tan', 'El enigma de la magia', 'Theresa Etxebarria', 2, 0),
#  (59, 'Elif Tan', 'El espejismo de la estrella fugaz', 'Wan Jimenez', 1, 0),
#  (59, 'Elif Tan', 'El secreto oscuro de el viajero', 'Wang Teles', 1, 0),
#  (9, 'Emiko Cruz', 'El laberinto de el hechizo', 'Pilar Ferreira', 3, 0),
#  (120, 'Emiko Diniz', 'El enigma de la luz', 'Umar Zapata', 2, 0),
#  (120, 'Emiko Diniz', 'Las aventuras de la esperanza', 'Ilya Ferreira', 1, 0),
#  (176, 'Emiko Martinez', 'El amanecer de el rey', 'Pilar Ferreira', 3, 0),
#  (176, 'Emiko Martinez', 'El arco iris de el laberinto', 'Tatiana Kawaguchi', 2, 0),
#  (176, 'Emiko Martinez', 'El último viaje de la tierra', 'Jin Bianchi', 3, 0),
#  (176, 'Emiko Martinez', 'El viaje de el río', 'Elif Ueno', 2, 0),
#  (161, 'Emiko Ramos', 'La doncella de la gruta', 'Valeria Henriquez', 3, 0),
#  (183, 'Fabiana Lopez', 'El ritual de la sonrisa', 'Yasmin Nguyen', 2, 0),
#  (183, 'Fabiana Lopez', 'La fuga de la caza', 'Fabiana Xu', 1, 0),
#  (183, 'Fabiana Lopez', 'La senda de la leyenda', 'Zara Duarte', 2, 0),
#  (198, 'Fabiana Xavier', 'La estirpe de el rey', 'Natalia Ortega', 1, 0),
#  (198, 'Fabiana Xavier', 'La fuga de la espada mágica', 'Tatiana Zapata', 1, 0),
#  (198, 'Fabiana Xavier', 'La misión de el laberinto', 'Hiroko Lopez', 2, 0),
#  (198, 'Fabiana Xavier', 'La odisea de la travesía', 'Umar Etxebarria', 2, 0),
#  (198, 'Fabiana Xavier', 'La travesía de el amanecer', 'Chen Lopes', 2, 0),
#  (158, 'Fadhila Oliveira', 'El laberinto de el hechizo', 'Pilar Ferreira', 3, 0),
#  (158, 'Fadhila Oliveira', 'La estirpe de la gruta', 'Chen Lopes', 2, 0),
#  (71, 'Fadhila Tan', 'El secreto de la verdad', 'Ursula Henriquez', 1, 0),
#  (71, 'Fadhila Tan', 'El vuelo de el fuego', 'Xavier Iglesias', 3, 0),
#  (71, 'Fadhila Tan', 'La trampa de el león', 'Salim Jimenez', 1, 0),
#  (71, 'Fadhila Tan', 'La travesía de el ángel', 'Qiu Esteves', 2, 0),
#  (102, 'Fadhila Teixeira', 'El secreto oscuro de la traición', 'Ilya Zapata', 3, 0),
#  (102, 'Fadhila Teixeira', 'La metamorfosis de la magia', 'Valentina Rocha', 1, 0),
#  (102, 'Fadhila Teixeira', 'La trampa de la cárcel', 'Zara Abadi', 10, 10),
#  (56, 'Genghis Cruz', 'La estirpe de el rey', 'Natalia Ortega', 1, 0),
#  (56, 'Genghis Cruz', 'La fuente de el ángel', 'Nadia Hidalgo', 1, 0),
#  (56, 'Genghis Cruz', 'La trampa de la cárcel', 'Zara Abadi', 10, 10),
#  (56, 'Genghis Cruz', 'La travesía de el ángel', 'Qiu Esteves', 2, 0),
#  (28, 'Genghis Uchoa', 'El lamento de el hechizo', 'Yasmin Watanabe', 3, 3),
#  (28, 'Genghis Uchoa', 'El secreto oscuro de el lamento', 'Qiu Diniz', 4, 4),
#  (38, 'Giovanni Borges', 'El castillo de la luz', 'Mehmet Estevez', 2, 0),
#  (38, 'Giovanni Borges', 'El secreto oscuro de el sol', 'Orhan Zapata', 1, 1),
#  (38, 'Giovanni Borges', 'El tesoro escondido de el fuego', 'Zafar Cruz', 4, 0),
#  (38, 'Giovanni Borges', 'La travesura de la montaña', 'Sakura Joaquim', 2, 2),
#  (156, 'Gustavo Duarte', 'El secreto oscuro de el sol', 'Orhan Zapata', 1, 1),
#  (84, 'Gustavo Figueiredo', 'El camino hacia la luna', 'Mehmet Velez', 3, 0),
#  (84, 'Gustavo Figueiredo', 'El cuento de hadas de la profecía', 'Rania Gomes', 1, 0),
#  (84, 'Gustavo Figueiredo', 'El renacimiento de la revelación', 'Umberto Gao', 1, 0),
#  (84, 'Gustavo Figueiredo', 'El tesoro escondido de la senda', 'Dmitri Ferreira', 1, 0),
#  (84, 'Gustavo Figueiredo', 'La cripta de la bruja', 'Rosa Sousa', 3, 0),
#  (84, 'Gustavo Figueiredo', 'La estirpe de la gruta', 'Chen Lopes', 2, 0),
#  (84, 'Gustavo Figueiredo', 'La travesía del océano de el pacto', 'Rosa Sousa', 3, 0),
#  (155, 'Gustavo Qian', 'El enigma de la guerra', 'Valeria Henriquez', 3, 0),
#  (155, 'Gustavo Qian', 'Las aventuras de la corrupción', 'Rosa Wu', 4, 0),
#  (32, 'Gustavo Rocha', 'El canto de sirena de el encuentro', 'Beatriz Oliveira', 4, 0),
#  (32, 'Gustavo Rocha', 'El viaje de el árbol', 'Katarina Pacheco', 4, 4),
#  (32, 'Gustavo Rocha', 'La conquista de el camino', 'Sakura Vargas', 1, 1),
#  (32, 'Gustavo Rocha', 'La cripta de la esperanza', 'Han Ramos', 1, 0),
#  (78, 'Gustavo Velez', 'El canto de sirena de el rincón', 'Jasmin Lima', 2, 0),
#  (78, 'Gustavo Velez', 'La misión de el laberinto', 'Hiroko Lopez', 2, 0),
#  (2, 'Gustavo Vieira', 'La doncella de la muralla', 'Zara Duarte', 2, 0),
#  (2, 'Gustavo Vieira', 'La travesía de el amanecer', 'Chen Lopes', 2, 0),
#  (114, 'Hanako Mendes', 'El viajero de la sirena', 'Khaled Watanabe', 3, 0),
#  (114, 'Hanako Mendes', 'La sombra de la espada mágica', 'Patricia Pacheco', 1, 0),
#  (114, 'Hanako Mendes', 'La travesía sin retorno de el bosque', 'Zara Abadi', 10, 10),
#  (135, 'Hanako Qian', 'El vuelo mágico de el volcán', 'Quintus Alvarez', 1, 0),
#  (135, 'Hanako Qian', 'La resurrección de la traición', 'Chiyoko Ferreira', 3, 0),
#  (135, 'Hanako Qian', 'La travesía sin retorno de la batalla', 'Umar Ueno', 3, 3),
#  (11, 'Hiroko Zambrano', 'El canto de sirena de la aventura', 'Jin Olivares', 1, 0),
#  (81, 'Ilya Gao', 'La doncella de la gruta', 'Valeria Henriquez', 3, 0),
#  (101, 'Ilya Janssen', 'El camino hacia la luna', 'Mehmet Velez', 3, 0),
#  (101, 'Ilya Janssen', 'El misterio de el guardián', 'Mehmet Olivares', 2, 0),
#  (101, 'Ilya Janssen', 'El regreso de el jardín', 'Yasmin Rodriguez', 1, 0),
#  (101, 'Ilya Janssen', 'El secreto oscuro de el viajero', 'Wang Teles', 1, 0),
#  (101, 'Ilya Janssen', 'La maldición del vampiro de el viaje', 'Darius Martinez', 2, 0),
#  (117, 'Irina Figueiredo', 'El viajero de la cascada', 'Xavier Yilmaz', 2, 2),
#  (117, 'Irina Figueiredo', 'El viajero de la espada mágica', 'Kamala Olivares', 3, 3),
#  (27, 'Isa Correia', 'El camino hacia la alianza', 'Kamala Hernandez', 4, 4),
#  (27, 'Isa Correia', 'La metamorfosis de el adiós', 'Zafar Cruz', 4, 0),
#  (27, 'Isa Correia', 'La redención de el muro', 'Fadhila Teles', 1, 0),
#  (27, 'Isa Correia', 'La travesura de la montaña', 'Sakura Joaquim', 2, 2),
#  (160, 'Isa Gao', 'El arco iris de la gruta', 'Katarina Nogueira', 3, 0),
#  (160, 'Isa Gao', 'El ritual de la sonrisa', 'Yasmin Nguyen', 2, 0),
#  (160, 'Isa Gao', 'La metamorfosis de el abismo', 'Elena Teles', 2, 0),
#  (160, 'Isa Gao', 'La rebelión de la guerra', 'Katarina Pacheco', 4, 4),
#  (82, 'Isa Gomes', 'El secreto de el atardecer', 'Elif Gomes', 1, 0),
#  (82, 'Isa Gomes', 'La estrella fugaz de la selva', 'Nina Qian', 1, 0),
#  (34, 'Jasmin Henriquez', 'El arco iris de el amor', 'Wilhelmina Teles', 1, 0),
#  (34, 'Jasmin Henriquez', 'El canto de sirena de el rincón', 'Jasmin Lima', 2, 0),
#  (34, 'Jasmin Henriquez', 'El espejismo de la academia', 'Salim Barros', 3, 0),
#  (34, 'Jasmin Henriquez', 'El misterio de el pacto', 'Emiko Santana', 2, 0),
#  (70, 'Jin Ivanov', 'El espejismo de el misterio', 'Elif Goncalves', 4, 0),
#  (70, 'Jin Ivanov', 'El prisionero de la sombra', 'Yasmin Watanabe', 3, 3),
#  (187, 'Kamala Quintana', 'El camino hacia la escuela', 'Salim Barros', 3, 0),
#  (187, 'Kamala Quintana', 'El ritual de el susurro', 'Fabiana Diniz', 2, 0),
#  (187, 'Kamala Quintana', 'La estirpe de el hechicero', 'Xavier Teixeira', 1, 0),
#  (187, 'Kamala Quintana', 'La fuente de la redención', 'Jasmin Lima', 2, 0),
#  (142, 'Katarina Bianchi', 'La cripta de la batalla', 'Qiu Diniz', 4, 4),
#  (142, 'Katarina Bianchi', 'La fuga de el amanecer', 'Chidike Xu', 2, 0),
#  (142, 'Katarina Bianchi', 'La invasión de la profecía', 'Lakshmi Nguyen', 4, 4),
#  (142, 'Katarina Bianchi', 'La llave de el monstruo', 'Elena Teles', 2, 0),
#  (142, 'Katarina Bianchi', 'La venganza de la resistencia', 'Patricia Hidalgo', 3, 3),
#  (21, 'Katarina Estevez', 'El lamento de la magia', 'Katarina Pacheco', 4, 4),
#  (21, 'Katarina Estevez', 'El viaje de el unicornio', 'Yasmin Nguyen', 2, 0),
#  (21, 'Katarina Estevez', 'La venganza de la alianza', 'Valeria Lopez', 2, 2),
#  (36, 'Lakshmi Inácio', 'El arco iris de el amor', 'Yuri Almeida', 2, 0),
#  (36, 'Lakshmi Inácio', 'El cuento de hadas de la profecía', 'Rania Gomes', 1, 0),
#  (113, 'Lakshmi Rodriguez', 'El destino de la estrella', 'Qiu Gomes', 2, 0),
#  (113, 'Lakshmi Rodriguez', 'El misterio de el guardián', 'Mehmet Olivares', 2, 0),
#  (113, 'Lakshmi Rodriguez', 'La sombra de la espada mágica', 'Patricia Pacheco', 1, 0),
#  (151, 'Lakshmi Yilmaz', 'El príncipe de la amistad', 'Chidike Petrov', 6, 6),
#  (151, 'Lakshmi Yilmaz', 'El ritual de el grito', 'Vivek Fernandes', 2, 0),
#  (75, 'Leonardo Iglesias', 'El lamento de el atardecer', 'Chen Barros', 3, 0),
#  (121, 'Leonardo Iglesias', 'El secreto de la desgracia', 'Vivek Joaquim', 1, 1),
#  (75, 'Leonardo Iglesias', 'El viaje de la corona', 'Umberto Fernandes', 1, 0),
#  (75, 'Leonardo Iglesias', 'El vuelo mágico de el volcán', 'Quintus Alvarez', 1, 0),
#  (75, 'Leonardo Iglesias', 'La cripta de la bruja', 'Rosa Sousa', 3, 0),
#  (148, 'Mehmet Estevez', 'El misterio de el guardián', 'Mehmet Olivares', 2, 0),
#  (55, 'Mehmet Vargas', 'El canto de sirena de la resistencia', 'Fabiana Diniz', 2, 0),
#  (191, 'Mikhail Pereira', 'El lamento de el hechizo', 'Yasmin Watanabe', 3, 3),
#  (191, 'Mikhail Pereira', 'La cripta de el hechizo', 'Leonardo Xia', 1, 0),
#  (191, 'Mikhail Pereira', 'La maldición del vampiro de la senda', 'Chen Bianchi', 2, 0),
#  (191, 'Mikhail Pereira', 'La trampa de la ciudad', 'Jasmin Joaquim', 3, 0),
#  (167, 'Mina Qian', 'El resurgimiento de el valle', 'Jin Bianchi', 3, 0),
#  (167, 'Mina Qian', 'La profecía de la escuela', 'Wilhelmina Xu', 2, 0),
#  (167, 'Mina Qian', 'La rebelión de la estrella', 'Beatriz Oliveira', 4, 0),
#  (45, 'Mina Rodriguez', 'El tesoro escondido de el fuego', 'Zafar Cruz', 4, 0),
#  (45, 'Mina Rodriguez', 'La fuente de la redención', 'Jasmin Lima', 2, 0),
#  (45, 'Mina Rodriguez', 'La odisea de el héroe', 'Isa Lima', 2, 0),
#  (138, 'Nadia Cruz', 'El misterio de la sombra', 'Beatriz Estevez', 2, 0),
#  (138, 'Nadia Cruz', 'El tesoro escondido de la venganza', 'Hanako Janssen', 4, 0),
#  (138, 'Nadia Cruz', 'La estirpe de el viajero', 'Yasmin Watanabe', 3, 3),
#  (199, 'Nadia Rocha', 'El secreto de el peligro', 'Yuri Vargas', 3, 0),
#  (199, 'Nadia Rocha', 'El secreto de la desgracia', 'Vivek Joaquim', 1, 1),
#  (199, 'Nadia Rocha', 'El vuelo de el desafío', 'Wan Joaquim', 4, 0),
#  (14, 'Nadia Tan', 'El bosque encantado de la mariposa', 'Han Rodriguez', 1, 0),
#  (14, 'Nadia Tan', 'El tesoro escondido de la luna', 'Kamala Hernandez', 4, 4),
#  (14, 'Nadia Tan', 'El viajero de la cascada', 'Xavier Yilmaz', 2, 2),
#  (39, 'Nadia Urbina', 'El caballero de el horizonte', 'Hiroko Lopez', 2, 0),
#  (39, 'Nadia Urbina', 'El prisionero de el amanecer', 'Katarina Gomes', 3, 0),
#  (39, 'Nadia Urbina', 'La canción de el secreto', 'Katarina Nogueira', 3, 0),
#  (39, 'Nadia Urbina', 'La odisea de la redención', 'Mehmet Velez', 3, 0),
#  (39, 'Nadia Urbina', 'La sombra de la oscuridad', 'Tatiana Barros', 2, 0),
#  (182, 'Nina Duarte', 'El lamento de el hechizo', 'Yasmin Watanabe', 3, 3),
#  (182, 'Nina Duarte', 'El viajero de la cascada', 'Xavier Yilmaz', 2, 2),
#  (182, 'Nina Duarte', 'La llegada de la aldea', 'Isa Joaquim', 1, 0),
#  (182, 'Nina Duarte', 'La venganza de la bruja', 'Fatemeh Kumar', 1, 0),
#  (182, 'Nina Duarte', 'Las aventuras de la corrupción', 'Rosa Wu', 4, 0),
#  (103, 'Nina Janssen', 'El arco iris de el rincón', 'Beatriz Oliveira', 4, 0),
#  (103, 'Nina Janssen', 'La cripta de la batalla', 'Qiu Diniz', 4, 4),
#  (103, 'Nina Janssen', 'La leyenda perdida de la selva', 'Tatjana Bianchi', 3, 3),
#  (103, 'Nina Janssen', 'La tormenta de el sueño', 'Gustavo Olivares', 2, 0),
#  (63, 'Nina Nogueira', 'El vuelo mágico de el legado', 'Zara Abadi', 10, 10),
#  (68, 'Nina Santos', 'La batalla de la fortuna', 'Umar Etxebarria', 2, 0),
#  (68, 'Nina Santos', 'La historia de el grito', 'Mikhail Borges', 1, 0),
#  (100, 'Omar Qian', 'La invasión de la travesía', 'Elif Goncalves', 4, 0),
#  (109, 'Orhan Petrov', 'El príncipe de la amistad', 'Chidike Petrov', 6, 6),
#  (109, 'Orhan Petrov', 'El tesoro escondido de el misterio', 'Yuri Almeida', 2, 0),
#  (24, 'Oscar Cruz', 'El tesoro escondido de la luna', 'Kamala Hernandez', 4, 4),
#  (96, 'Oscar Lima', 'El canto de sirena de la aventura', 'Jin Olivares', 1, 0),
#  (43, 'Parvati Kawaguchi', 'El príncipe de la amistad', 'Chidike Petrov', 6, 6),
#  (92, 'Patricia Goncalves', 'La travesía de el muro', 'Parvati Correia', 1, 0),
#  (69, 'Pilar Borges', 'El arco iris de el rincón', 'Beatriz Oliveira', 4, 0),
#  (57, 'Pilar Nguyen', 'El cuento de hadas de el rincón', 'Katarina Dutta', 2, 0),
#  (57, 'Pilar Nguyen', 'La fuga de el amanecer', 'Chidike Xu', 2, 0),
#  (57, 'Pilar Nguyen', 'La odisea de el héroe', 'Isa Lima', 2, 0),
#  (179, 'Qiu Oliveira', 'El destino de la ley', 'Elif Ueno', 2, 0),
#  (179, 'Qiu Oliveira', 'El tesoro de la clave', 'Leticia Xia', 8, 8),
#  (179, 'Qiu Oliveira', 'La sombra de la estrella', 'Jin Wu', 3, 3),
#  (66, 'Quentin Estevez', 'El ritual de el grito', 'Vivek Fernandes', 2, 0),
#  (66, 'Quentin Estevez', 'La metamorfosis de la fortuna', 'Quentin Vargas', 3, 0),
#  (111, 'Quentin Pereira', 'El lamento de la aldea', 'Umar Nguyen', 1, 0),
#  (111, 'Quentin Pereira', 'El resurgimiento de el valle', 'Jin Bianchi', 3, 0),
#  (111, 'Quentin Pereira', 'El secreto oscuro de el puente', 'Yuri Vargas', 3, 0),
#  (137, 'Quintus Hidalgo', 'El tesoro de el renacer', 'Tatjana Bianchi', 3, 3),
#  (137, 'Quintus Hidalgo', 'La búsqueda del tesoro de el sacrificio', 'Katarina Nogueira', 3, 0),
#  (137, 'Quintus Hidalgo', 'La venganza de la resistencia', 'Patricia Hidalgo', 3, 3),
#  (3, 'Quintus Teixeira', 'La batalla de la fortuna', 'Umar Etxebarria', 2, 0),
#  (3, 'Quintus Teixeira', 'La historia de la verdad', 'Valeria Henriquez', 3, 0),
#  (3, 'Quintus Teixeira', 'La travesía sin retorno de la guerra', 'Theresa Etxebarria', 2, 0),
#  (175, 'Rashid Lima', 'El arco iris de el rincón', 'Beatriz Oliveira', 4, 0),
#  (175, 'Rashid Lima', 'El castillo de la profecía', 'Qiu Abadi', 1, 0),
#  (175, 'Rashid Lima', 'El enigma de la paz', 'Hanako Teles', 1, 0),
#  (175, 'Rashid Lima', 'La metamorfosis de la luz', 'Sakura Joaquim', 2, 2),
#  (93, 'Rashid Nogueira', 'El regreso de la montaña', 'Jin Wu', 3, 3),
#  (93, 'Rashid Nogueira', 'La invasión de el monstruo', 'Quentin Vargas', 3, 0),
#  (93, 'Rashid Nogueira', 'La travesía de el laberinto', 'Darius Joaquim', 1, 0),
#  (104, 'Rashid Nunes', 'El lamento de la magia', 'Katarina Pacheco', 4, 4),
#  (104, 'Rashid Nunes', 'El prisionero de la bruma', 'Quentin Borges', 2, 2),
#  (104, 'Rashid Nunes', 'El secreto de la desgracia', 'Vivek Joaquim', 1, 1),
#  (104, 'Rashid Nunes', 'La canción de el secreto', 'Katarina Nogueira', 3, 0),
#  (104, 'Rashid Nunes', 'La llave de la luna', 'Zafar Cruz', 4, 0),
#  (173, 'Rosa Carvalho', 'El misterio de el guardián', 'Mehmet Olivares', 2, 0),
#  (166, 'Rosa Santana', 'El bosque encantado de la libertad', 'Chidike Petrov', 6, 6),
#  (166, 'Rosa Santana', 'La historia de la verdad', 'Valeria Henriquez', 3, 0),
#  (166, 'Rosa Santana', 'La odisea de el héroe', 'Isa Lima', 2, 0),
#  (166, 'Rosa Santana', 'La sombra de la luna', 'Qiu Etxebarria', 2, 0),
#  (140, 'Rosa Santos', 'El canto de sirena de el guerrero', 'Genghis Urbina', 2, 0),
#  (140, 'Rosa Santos', 'El grito de el tesoro', 'Wang Correia', 2, 0),
#  (140, 'Rosa Santos', 'El lamento de la magia', 'Katarina Pacheco', 4, 4),
#  (140, 'Rosa Santos', 'La metamorfosis de la luz', 'Sakura Joaquim', 2, 2),
#  (140, 'Rosa Santos', 'La travesura de la montaña', 'Sakura Joaquim', 2, 2),
#  (87, 'Sakura Xu', 'El castillo de la profecía', 'Qiu Abadi', 1, 0),
#  (87, 'Sakura Xu', 'La maldición de la corrupción', 'Tatiana Yan', 3, 0),
#  (87, 'Sakura Xu', 'La travesura de la redención', 'Lakshmi Nguyen', 4, 4),
#  (42, 'Salim Figueiredo', 'El príncipe de el atardecer', 'Quintus Mendes', 1, 0),
#  (42, 'Salim Figueiredo', 'El secreto oscuro de la cascada', 'Oscar Ferreira', 1, 0),
#  (42, 'Salim Figueiredo', 'La sombra de la espada mágica', 'Patricia Pacheco', 1, 0),
#  (42, 'Salim Figueiredo', 'La trampa de la ciudad', 'Jasmin Joaquim', 3, 0),
#  (107, 'Salim Iglesias', 'El misterio de el pacto', 'Emiko Santana', 2, 0),
#  (107, 'Salim Iglesias', 'El refugio de la despedida', 'Kamala Olivares', 3, 3),
#  (107, 'Salim Iglesias', 'La invasión de el destino', 'Rosa Wu', 4, 0),
#  (74, 'Samir Estevez', 'El camino hacia la alianza', 'Kamala Hernandez', 4, 4),
#  (115, 'Samir Lopes', 'El arco iris de la gruta', 'Katarina Nogueira', 3, 0),
#  (115, 'Samir Lopes', 'El eclipse de la aventura', 'Beatriz Oliveira', 4, 0),
#  (115, 'Samir Lopes', 'El laberinto de el hechizo', 'Pilar Ferreira', 3, 0),
#  (115, 'Samir Lopes', 'El viajero de la sirena', 'Khaled Watanabe', 3, 0),
#  (115, 'Samir Lopes', 'La búsqueda de la estrella', 'Khaled Vargas', 1, 0),
#  (115, 'Samir Lopes', 'La cripta de la bruja', 'Rosa Sousa', 3, 0),
#  (115, 'Samir Lopes', 'La maldición de la corrupción', 'Tatiana Yan', 3, 0),
#  (172, 'Samir Oliveira', 'La danza macabra de el laberinto', 'Akira Qian', 3, 0),
#  (172, 'Samir Oliveira', 'La escalada de la muralla', 'Umar Ueno', 3, 3),
#  (61, 'Tatiana Inácio', 'El guardián de el guerrero', 'Leticia Xia', 8, 8),
#  (4, 'Tatiana Zhang', 'El guardián de la luna', 'Valeria Kumar', 3, 0),
#  (4, 'Tatiana Zhang', 'La fuente de la muralla', 'Hanako Janssen', 4, 0),
#  (4, 'Tatiana Zhang', 'La odisea de el héroe', 'Isa Lima', 2, 0),
#  (37, 'Theresa Nunes', 'El espejismo de el misterio', 'Elif Goncalves', 4, 0),
#  (37, 'Theresa Nunes', 'El tesoro escondido de el misterio', 'Yuri Almeida', 2, 0),
#  (37, 'Theresa Nunes', 'La profecía de el puente', 'Leticia Velez', 1, 0),
#  (23, 'Umberto Teles', 'El despertar de la esperanza', 'Jasmin Joaquim', 3, 0),
#  (23, 'Umberto Teles', 'El prisionero de el ángel', 'Quentin Vargas', 3, 0),
#  (23, 'Umberto Teles', 'La llave de el dragón', 'Kamala Olivares', 3, 3),
#  (200, 'Ursula Lima', 'La escalada de la muralla', 'Umar Ueno', 3, 3),
#  (200, 'Ursula Lima', 'La fuga de la espada mágica', 'Tatiana Zapata', 1, 0),
#  (170, 'Ursula Velez', 'El caballero de la muralla', 'Xin Goncalves', 1, 0),
#  (170, 'Ursula Velez', 'El espejismo de el río', 'Khaled Xia', 1, 0),
#  (170, 'Ursula Velez', 'La maldición de la corrupción', 'Tatiana Yan', 3, 0),
#  (25, 'Valentina Vieira', 'El tesoro escondido de la senda', 'Bianca Ramos', 2, 0),
#  (197, 'Valentina Wu', 'El cuento de hadas de el mito', 'Chen Barros', 3, 0),
#  (197, 'Valentina Wu', 'El resurgimiento de el amanecer', 'Khaled Watanabe', 3, 0),
#  (197, 'Valentina Wu', 'El tesoro escondido de el misterio', 'Yuri Almeida', 2, 0),
#  (185, 'Valeria Qian', 'El castillo de la senda', 'Wan Joaquim', 4, 0),
#  (13, 'Valeria Vargas', 'La llegada de la aldea', 'Isa Joaquim', 1, 0),
#  (13, 'Valeria Vargas', 'La trampa de la ciudad', 'Jasmin Joaquim', 3, 0),
#  (65, 'Vivek Lima', 'El prisionero de el ángel', 'Quentin Vargas', 3, 0),
#  (65, 'Vivek Lima', 'El secreto de la leyenda', 'Zoya Wu', 1, 0),
#  (65, 'Vivek Lima', 'La historia de el grito', 'Mikhail Borges', 1, 0),
#  (65, 'Vivek Lima', 'La venganza de la montaña', 'Chidike Xu', 2, 0),
#  (125, 'Vivek Nogueira', 'El misterio de el guardián', 'Mehmet Olivares', 2, 0),
#  (125, 'Vivek Nogueira', 'El viaje de el río', 'Elif Ueno', 2, 0),
#  (125, 'Vivek Nogueira', 'La doncella de la corona', 'Beatriz Estevez', 2, 0),
#  (125, 'Vivek Nogueira', 'La odisea de el héroe', 'Isa Lima', 2, 0),
#  (35, 'Vivek Xu', 'El arco iris de el laberinto', 'Tatiana Kawaguchi', 2, 0),
#  (35, 'Vivek Xu', 'El canto de sirena de la resistencia', 'Fabiana Diniz', 2, 0),
#  (35, 'Vivek Xu', 'El secreto oscuro de la maraña', 'Katarina Gomes', 3, 0),
#  (35, 'Vivek Xu', 'La estirpe de el hechicero', 'Xavier Teixeira', 1, 0),
#  (29, 'Wan Qian', 'La travesía de el laberinto', 'Darius Joaquim', 1, 0),
#  (29, 'Wan Qian', 'Las aventuras de la esperanza', 'Ilya Ferreira', 1, 0),
#  (73, 'Wan Rodriguez', 'La escalada de la bestia', 'Wan Joaquim', 4, 0),
#  (112, 'Wan Yamamoto', 'Las aventuras de el abismo', 'Javier Martinez', 2, 0),
#  (164, 'Wang Dutta', 'El viajero de la espada mágica', 'Kamala Olivares', 3, 3),
#  (130, 'Wilhelmina Pereira', 'El canto de sirena de el rincón', 'Jasmin Lima', 2, 0),
#  (196, 'Xavier Barros', 'El caballero de el horizonte', 'Hiroko Lopez', 2, 0),
#  (196, 'Xavier Barros', 'La escalada de la bestia', 'Wan Joaquim', 4, 0),
#  (18, 'Xavier Rodriguez', 'El amanecer de el héroe', 'Yuri Ivanov', 1, 0),
#  (18, 'Xavier Rodriguez', 'La batalla de el árbol', 'Lakshmi Nguyen', 4, 4),
#  (18, 'Xavier Rodriguez', 'La rebelión de el unicornio', 'Mikhail Lopes', 1, 0),
#  (127, 'Xavier Watanabe', 'El arco iris de la gruta', 'Katarina Nogueira', 3, 0),
#  (127, 'Xavier Watanabe', 'El prisionero de el amanecer', 'Katarina Gomes', 3, 0),
#  (127, 'Xavier Watanabe', 'El renacimiento de la revelación', 'Umberto Gao', 1, 0),
#  (127, 'Xavier Watanabe', 'El tesoro escondido de la senda', 'Dmitri Ferreira', 1, 0),
#  (127, 'Xavier Watanabe', 'La batalla de el árbol', 'Lakshmi Nguyen', 4, 4),
#  (147, 'Yasmin Zambrano', 'La invasión de la profecía', 'Lakshmi Nguyen', 4, 4),
#  (147, 'Yasmin Zambrano', 'La travesía de el ángel', 'Qiu Esteves', 2, 0),
#  (174, 'Yuri Estevez', 'La rebelión de la academia', 'Qiu Teles', 1, 0),
#  (15, 'Yusef Joaquim', 'El despertar de el jardín', 'Valeria Kumar', 3, 0),
#  (15, 'Yusef Joaquim', 'El secreto oscuro de la traición', 'Ilya Zapata', 3, 0),
#  (15, 'Yusef Joaquim', 'El viaje de el árbol', 'Katarina Pacheco', 4, 4),
#  (15, 'Yusef Joaquim', 'El vuelo mágico de el volcán', 'Quintus Alvarez', 1, 0),
#  (124, 'Yusef Qian', 'La maldición de el laberinto', 'Leticia Xia', 8, 8),
#  (106, 'Yusef Rodriguez', 'La estirpe de el viajero', 'Yasmin Watanabe', 3, 3),
#  (91, 'Zafar Duarte', 'La fuente de la redención', 'Jasmin Lima', 2, 0),
#  (136, 'Zafar Hidalgo', 'El caballero de la flor', 'Tatiana Yan', 3, 0),
#  (136, 'Zafar Hidalgo', 'El regreso de la montaña', 'Jin Wu', 3, 3),
#  (194, 'Zafar Queiroz', 'La danza macabra de el héroe', 'Natalia Qian', 1, 0),
#  (194, 'Zafar Queiroz', 'La odisea de la estrella', 'Isa Qian', 2, 0),
#  (194, 'Zafar Queiroz', 'La rebelión de la noche', 'Zara Inácio', 2, 0),
#  (79, 'Zafar Rocha', 'El viaje de el ángel', 'Tatiana Kawaguchi', 2, 0),
#  (165, 'Zafar Vieira', 'El ritual de la maraña', 'Mina Borges', 1, 0),
#  (94, 'Zafar Xavier', 'El hechizo de la luz', 'Rosa Wu', 4, 0),
#  (94, 'Zafar Xavier', 'La fortuna de el tesoro', 'Pilar Ferreira', 3, 0),
#  (145, 'Zafar Yilmaz', 'La senda de la leyenda', 'Zara Duarte', 2, 0),
#  (145, 'Zafar Yilmaz', 'La tormenta de la caverna', 'Chen Barros', 1, 0),
#  (5, 'Zara Almeida', 'La batalla de la fortuna', 'Umar Etxebarria', 2, 0),
#  (5, 'Zara Almeida', 'La estirpe de el amor', 'Isa Lima', 2, 0),
#  (48, 'Zara Kawaguchi', 'El prisionero de el ángel', 'Quentin Vargas', 3, 0),
#  (48, 'Zara Kawaguchi', 'El secreto oscuro de la cascada', 'Oscar Ferreira', 1, 0),
#  (1, 'Zara Ueno', 'La batalla de el peligro', 'Patricia Xia', 1, 0),
#  (30, 'Zoya Janssen', 'El bosque encantado de el lamento', 'Chidike Petrov', 6, 6),
#  (30, 'Zoya Janssen', 'La leyenda de el guardián', 'Zara Abadi', 10, 10),
#  (30, 'Zoya Janssen', 'La llegada de la despedida', 'Genghis Urbina', 2, 0),
#  (30, 'Zoya Janssen', 'La misión de el laberinto', 'Hiroko Lopez', 2, 0),
#  (16, 'Zoya Lopes', 'La leyenda de el guardián', 'Zara Abadi', 10, 10),
#  (16, 'Zoya Lopes', 'La odisea de la travesía', 'Umar Etxebarria', 2, 0),
#  (16, 'Zoya Lopes', 'La senda de la leyenda', 'Zara Duarte', 2, 0),
#  (16, 'Zoya Lopes', 'La travesía sin retorno de la bruma', 'Parvati Alvarez', 1, 0),
#  (143, 'Zoya Lopez', 'El bosque encantado de el camino', 'Tatjana Bianchi', 3, 3),
#  (143, 'Zoya Lopez', 'El príncipe de el susurro', 'Aarav Quintana', 1, 0),
#  (143, 'Zoya Lopez', 'La rebelión de la academia', 'Qiu Teles', 1, 0),
#  (143, 'Zoya Lopez', 'La travesía de la cárcel', 'Fabiana Etxebarria', 2, 0)]

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=cafe4e99-499e-4e36-b9fd-48e2d31e0196' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
